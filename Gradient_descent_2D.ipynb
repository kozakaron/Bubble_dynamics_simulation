# %% [markdown]
# ## Importing libraries, parameters.py

# %%
"""Create parameters.py and load it"""

# Directory for .inp file:
path = 'INP file examples\\chem_Otomo2018_without_O.inp'

# import libraries:
import importlib   # For reloading your own files
from termcolor import colored   # for colored error messages

# import inp_data_extractor.py as inp:
try:
    import inp_data_extractor as inp
except ImportError:
    try:
        from Bubble_dynamics_simulation import inp_data_extractor as inp
    except ImportError as error:
        print(colored(f'Error, \'inp_data_extractor.py\' not found', 'red'))
        raise error
    except Exception as error:
        print(colored(f'Error, \'inp_data_extractor.py\' failed to load', 'red'))
        raise error
except Exception as error:
    print(colored(f'Error, \'inp_data_extractor.py\' failed to load', 'red'))
    raise error
importlib.reload(inp)   # reload changes you made

# create parameters.py
inp.extract(path)

import parameters as par   # numeric constants and coefficents
importlib.reload(par)   # reload changes you made
print(par.model)
# Out:
# path=INP file examples\chem_Otomo2018_without_O.inp
# Note, lambda value for specie 'H' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NH2' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NH' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NNH' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H4' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H3' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H2' is not in data.py: 0.0 is used
# Note, lambda value for specie 'H2NN' is not in data.py: 0.0 is used
# Warning, third body 'H2O' is not in species in line 64 (' H2/2.5/ H2O/12/ AR/0.0/ ') in reaction 'H2+M=H+H+M'
# Warning, third body 'AR' is not in species in line 64 (' H2/2.5/ H2O/12/ AR/0.0/ ') in reaction 'H2+M=H+H+M'
# model: chem_Otomo2018_without_O
# File 'parameters.py' succesfully created
# chem_Otomo2018_without_O

# %%
"""Libraries"""

# for plotting:
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

import numpy as np   # matrices, math
import time   # runtime measurement
import os    # file management
import pandas as pd   # data frames
from multiprocessing import Pool, cpu_count   # multithreading
import importlib   # reload changes you made

# import gradient_descent.py as gd:
_already_imported = 'gd' in globals()
try:
    import gradient_descent as gd
except ImportError:
    try:
        from  Bubble_dynamics_simulation import gradient_descent as gd
    except ImportError as _error:
        print(colored(f'Error, \'gradient_descent.py\' not found', 'red'))
        raise _error
    except Exception as _error:
        print(colored(f'Error, \'gradient_descent.py\' failed to load', 'red'))
        raise _error
except Exception as _error:
    print(colored(f'Error, \'gradient_descent.py\' failed to load', 'red'))
    raise _error
if _already_imported: importlib.reload(gd)   # reload changes you made
# Out:
# model: chem_Otomo2018_without_O
# target specie: NH3
# excitation: sin_impulse (control parameters: ['p_A', 'freq', 'n'])
# enable heat transfer: True	enable evaporation: False	enable reactions: True	enable dissipated energy: True

# %% [markdown]
# ## Ranges, settings

# %%
# Control parameter ranges
# make sure, it's only 2D

ranges = dict(
  # Initial conditions:
    # bubble equilibrium radius [m]
    R_E = [1e-6*x for x in [5.0, 125.0]], # [um --> m]
    # initial radius / equilibrium radius R_0/R_E [-]
    ratio = [1.0],
    # indexes of species in initial bubble
    gases=[[par.index['N2'], par.index['H2']]],
    # Molar fractions of species in the initial bubble (H2 and N2) [-]
    fractions=[[0.25, 0.75]],
  # Ambient parameters:
    # ambient pressure [Pa]
    P_amb = [x * par.atm2Pa for x in [1.0]], # [atm --> Pa]
    # ambient temperature [K]       
    T_inf = [par.absolute_zero + x for x in [20.0]], # [°C --> K]
  # Liquid parameters:
    # water accommodation coefficient [-]
    alfa_M = [0.35],
    # vapour pressure [Pa]
    #P_v = par.P_v, # calculated from T_inf
    # dynamic viscosity [Pa*s]
    #mu_L = par.mu_L, # calculated from T_inf
    # density [kg/m^3]
    rho_L =  [998.20],
    # sound speed [m/s]
    c_L = [par.c_L],
    # surfactant (surface tension modfier) [-]
    surfactant = [1.0],
  # Excitation parameters: (excitation_type = sin_impulse)
    # excitation amplitude [Pa]
    p_A = [-x * par.bar2Pa for x in [1.0, 3.0]], # [bar --> Pa]
    # excitation frequency [Hz]
    freq =  [20000.00],
    # excitation duration in period times [-]
    n =  [1.00],
)

for key in gd.de.excitation_args:
    if key not in ranges:
        print(colored(f'Error, {key} not in ranges', 'red'))

examined_keys = []
for key in ranges:
    if len(ranges[key]) > 1:
        examined_keys.append(key)

print(f'The following control parameters will be examined: {examined_keys}')
if len(examined_keys) != 2:
    print(colored(f'Error, exactly 2 control parameters have to be examined', 'red'))
key1 = examined_keys[0]
key2 = examined_keys[1]
# Out:
# The following control parameters will be examined: ['R_E', 'p_A']

# %%
# Settings:
to_optimize = 'energy_demand'   # key in data from de.get_data()
directory = 'test_1atm_20000Hz_2D'   # appropiate 2D bruteforce parameter study
file_base_name = 'output_'

# %% [markdown]
# ## Reading files, 2D contour plot
# This is optional, you don't have to place a contour plot underneath the gadient descent visualization.
# The bruteforce param study should be 2D with the same range as above, and uniform spacement.

# %%
# create a dataframe
all_data = pd.DataFrame()
num = 0

# iterate trough all files in directory (including subdirectories)
for (root, dirs, files) in os.walk(directory):
    for file in files:
        # ignore python rubish
        if 'ipynb_checkpoints' in root:
            continue
        # check if it's a CSV starting with file_base_name
        if file[-4:] != '.csv':
            continue
        if file[:len(file_base_name)] != file_base_name:
            continue

        # read file
        num += 1
        current_data = pd.read_csv(os.path.join(root, file))

        # Cast object-dtype columns with all-bool values to bool dtype
        for col in current_data.columns:
            if current_data[col].dtype == 'object' and all(current_data[col].dropna().map(lambda x: isinstance(x, bool))):
                current_data[col] = current_data[col].astype(bool)

                
        print(f'\t{file: <24} ({current_data.shape[0]: >4} rows)')
        all_data = pd.concat([all_data, current_data])

# locate successful simulations (or use all_data['success'] == True)
good_data = all_data.loc[
    (all_data['error_code'] % 100 <= 3) & ((all_data['error_code'] // 100) % 10 != 1) &
    (all_data['energy_demand'] > 0.0) & (all_data['energy_demand'] == all_data['energy_demand']) # positive not NaN
]

good_data = good_data.sort_values(['ID'], ascending=True)
print(f'Good data: {good_data.shape[0]} rows ({100*good_data.shape[0]/all_data.shape[0]: .2f} %)')
# Out:
# 	output_1.csv             (1001 rows)
# 	output_2.csv             (1001 rows)
# 	output_3.csv             ( 498 rows)
# Good data: 2457 rows ( 98.28 %)

# %%
# Check ranges vs good_data:
for key in ranges:
    llist = good_data[key].unique()
    llist.sort()
    if len(llist) > 1 and len(ranges[key]) < 2:
        print(colored(f'Error, {key} has {len(llist)} distinct values, but it should be constant {ranges[key][0]}', 'red'))
    if len(ranges[key]) > 1:
        if len(llist) < 2:
            print(colored(f'Error, {key} should have  values between {ranges[key][0]} and {ranges[key][1]}', 'red'))
        if abs(llist[0] - min(ranges[key])) / abs(min(ranges[key]) + 1e-10) > 1e-5:
            print(colored(f'Error, {key} has values between {llist[0]} and {llist[-1]}, but it should be between {ranges[key][0]} and {ranges[key][1]}', 'red'))
        if abs(llist[-1] - max(ranges[key])) / abs(max(ranges[key]) + 1e-10) > 1e-5:
            print(colored(f'Error, {key} has values between {llist[0]} and {llist[-1]}, but it should be between {ranges[key][0]} and {ranges[key][1]}', 'red'))

# %%
# list unique values:

output_list = list(good_data[to_optimize])
list1 = list(good_data[key1])
list2 = list(good_data[key2])
value_list1 = good_data[key1].unique()
value_list2 = good_data[key2].unique()
value_list1.sort()
value_list2.sort()
print(f'{key1}: from {value_list1[0]} to {value_list1[-1]} ({len(value_list1)} values)')
print(f'{key2}: from {value_list2[0]} to {value_list2[-1]} ({len(value_list2)} values)')
# Out:
# R_E: from 5e-06 to 0.000125 (50 values)
# p_A: from -300000.0 to -100000.0 (50 values)

# %%
# Interpolate missing values
# Settings:
catch_outliers = True
use_log10 = True
fix_missing_values = True

# Assemble meshgrid, and existing data points:
combined = []   # (key1, key2) pairs in order
output_list = []    # values of to_optimize in the sameorder
for x in value_list1:
    for y in value_list2:
        energy = good_data.loc[(good_data[key1] == x) & (good_data[key2] == y), to_optimize]
        if len(energy) == 1:
            energy = energy.values[0]
            combined.append((x, y))
            output_list.append(energy)
            
if use_log10:
    output_list = list(np.log10(output_list))
vmin = min(output_list) # min
vmax = 2.0*vmin if use_log10 else 100.0*vmin    # max
X, Y = np.meshgrid(value_list1, value_list2)
Z = np.zeros(X.shape)
fixed = 0

# Iterate trough all possible combinations:
for i, x in enumerate(value_list1):
    for j, y in enumerate(value_list2):
        if (x, y) not in combined:  # missing values
            index = i * len(value_list2) + j
            y1 = combined[index-1][1]; y2 = combined[index][1]
            o1 = output_list[index-1]; o2 = output_list[index]
            if abs(y2 - y1) > 0.3*abs(value_list2[-1] - value_list2[0]):
                # if the gap of missing values is too large
                extrapolation = 30.0 if use_log10 else 1e30
            else:
                # linear interpolation
                extrapolation = o1 + (o2 - o1) * (y - y1) / (y2 - y1)

            combined = combined[:index] + [(x, y)] + combined[index:]
            if fix_missing_values:
                output_list = output_list[:index] + [extrapolation] + output_list[index:]
            else:
                output_list = output_list[:index] + [vmax] + output_list[index:]
            Z[j, i] = output_list[index]
            fixed += 1

        else: # outliers
            index = combined.index((x, y))
            big = 2.0 if use_log10 else 100000.0 # ratio of outlier and neigbouring value

            if (i != 0 and i != len(value_list1)-1 and # not on the edge
                j != 0 and j != len(value_list2)-1 and  # not on the edge
                output_list[index-1] < vmax and output_list[index+1] < vmax and    # neighbouring values are not too big
                output_list[index] > big*output_list[index+1] and    # much bigger than the next
                output_list[index] > big*output_list[index-1] and catch_outliers):   # much bigger than the previous

                output_list[index] = (output_list[index-1] + output_list[index+1]) / 2
                print(f'{index}: {key1}={x : .4e}, {key2}={y: .4e}, output={output_list[index]: .3f}')
            Z[j, i] = output_list[index]
            

print(f'{fixed} missing values fixed')
# Out:
# 43 missing values fixed

# %%
# Plot:
contour_levels = 20
title = ''
xlabel = key1
ylabel = key2

fig,ax=plt.subplots(1, 1, figsize=(12, 10))
levels = np.linspace(vmin, vmax, 250)
cp = ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=vmax, extend='max')
ax.contour(X, Y, Z, levels=np.linspace(vmin, vmax, contour_levels), colors='black', linewidths=0.5)
colorbar_title = '$Energy\ demand\ [MJ/kg_{' + gd.de.target_specie + '}]$'
cbar = fig.colorbar(cp, label=colorbar_title) # Add a colorbar to a plot
ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ticks = cbar.get_ticks()
cbar.set_ticks(ticks)
if use_log10:
    cbar.set_ticklabels([f'{10**tick:.0f}' for tick in ticks])  # Format as powers of 10
else:
    cbar.set_ticklabels([f'{tick:.1f}' for tick in ticks])
cbar.ax.tick_params(labelsize=12)  # Adjust font size
plt.show()

# %% [markdown]
# ## Plot gradient descent search

# %%
# Generate random starting_point:

start_point = gd.rand_point(ranges, padding=0.01)   # random point in ranges

print(f'Starting point: ({key1}={start_point[key1]}, {key2}={start_point[key2]})')
data, success = gd.evaluate(start_point, to_optimize, t_int=[0.0, 1.0], LSODA_timeout=10, Radau_timeout=0)
if not success:
    print(colored(f'Error, simulation failed', 'red'))
else:
    print(f'Output in starting point: {data[to_optimize]: .4f}')

# Plot:

fig,ax=plt.subplots(1, 1, figsize=(4, 4))
levels = np.linspace(vmin, vmax, 100)
ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=vmax, extend='max')
ax.scatter(start_point[key1], start_point[key2], color='black', s=100, label='Starting point')
ax.axis('off')
plt.show()
# Out:
# Starting point: (R_E=1.7443360461243972e-05, p_A=-110717.70988315406)
# Output in starting point:  5267570080028.6338

# %%
start_point_copy = gd.de.copy(start_point)

datas, last_bests, elapsed_time = gd.gradient_descent(
    ranges=ranges, path='', to_optimize=to_optimize, start_point=start_point_copy,
    step_limit=100, first_step=0.01, min_step=1e-4, delta=1e-5,
    verbose=True, t_int=np.array([0.0, 1.0]), LSODA_timeout=10.0, Radau_timeout=0.0
)
# Out:
# 0. step; last_best= 5.26573e+12; absolute_best= 5.26573e+12; step_size= 0.01000
# 	point   =(R_E= 1.744336e-05; p_A=-1.107177e+05; )
# 	output  =5546846.944343622; success=True; modifier=4.0;
# 	gradient=(R_E=-0.0672; p_A= 0.9977; )
# 	change  =(R_E= 3.226602e-07; p_A=-7.981905e+03; )
# 1. step; last_best= 5.54685e+06; absolute_best= 5.54685e+06; step_size= 0.04000
# 	point   =(R_E= 1.776602e-05; p_A=-1.186996e+05; )
# 	output  =1426.093108776614; success=True; modifier=4.0;
# 	gradient=(R_E= 0.0862; p_A= 0.9963; )
# 	change  =(R_E=-1.654406e-06; p_A=-3.188098e+04; )
# 2. step; last_best= 1.42603e+03; absolute_best= 1.42603e+03; step_size= 0.16000
# 	point   =(R_E= 1.611161e-05; p_A=-1.505806e+05; )
# 	output  =1687.926629957094; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9909; p_A=-0.1347; )
# 	change  =(R_E= 4.756268e-06; p_A= 1.077441e+03; )
# 3. step; last_best= 1.68793e+03; absolute_best= 1.42603e+03; step_size= 0.04000
# 	point   =(R_E= 2.086788e-05; p_A=-1.495032e+05; )
# 	output  =1323.1890709509278; success=True; modifier=0.5;
# 	gradient=(R_E= 0.4684; p_A= 0.8835; )
# 	change  =(R_E=-1.124156e-06; p_A=-3.534070e+03; )
# 4. step; last_best= 1.32319e+03; absolute_best= 1.32319e+03; step_size= 0.02000
# 	point   =(R_E= 1.974373e-05; p_A=-1.530372e+05; )
# 	output  =1299.265504918516; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1908; p_A= 0.9816; )
# 	change  =(R_E=-2.290152e-07; p_A=-1.963240e+03; )
# 5. step; last_best= 1.29922e+03; absolute_best= 1.29922e+03; step_size= 0.01000
# 	point   =(R_E= 1.951471e-05; p_A=-1.550005e+05; )
# 	output  =1284.8099293790362; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9844; p_A=-0.1760; )
# 	change  =(R_E= 1.181272e-06; p_A= 3.519643e+02; )
# 6. step; last_best= 1.28481e+03; absolute_best= 1.28481e+03; step_size= 0.01000
# 	point   =(R_E= 2.069598e-05; p_A=-1.546485e+05; )
# 	output  =1269.2031942915305; success=True; modifier=0.5;
# 	gradient=(R_E= 0.0939; p_A= 0.9956; )
# 	change  =(R_E=-5.635153e-08; p_A=-9.955798e+02; )
# 7. step; last_best= 1.26918e+03; absolute_best= 1.26918e+03; step_size= 0.00500
# 	point   =(R_E= 2.063963e-05; p_A=-1.556441e+05; )
# 	output  =1218.5873091864619; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7683; p_A= 0.6401; )
# 	change  =(R_E= 1.843803e-06; p_A=-2.560594e+03; )
# 8. step; last_best= 1.21857e+03; absolute_best= 1.21857e+03; step_size= 0.02000
# 	point   =(R_E= 2.248343e-05; p_A=-1.582047e+05; )
# 	output  =1119.5735671068542; success=True; modifier=4.0;
# 	gradient=(R_E=-0.8368; p_A= 0.5475; )
# 	change  =(R_E= 8.033226e-06; p_A=-8.760276e+03; )
# 9. step; last_best= 1.11957e+03; absolute_best= 1.11957e+03; step_size= 0.08000
# 	point   =(R_E= 3.051666e-05; p_A=-1.669650e+05; )
# 	output  =1098.0042533246733; success=True; modifier=0.25;
# 	gradient=(R_E= 0.5183; p_A= 0.8552; )
# 	change  =(R_E=-1.243883e-06; p_A=-3.420833e+03; )
# 10. step; last_best= 1.09797e+03; absolute_best= 1.09797e+03; step_size= 0.02000
# 	point   =(R_E= 2.927278e-05; p_A=-1.703858e+05; )
# 	output  =1076.7659744642397; success=True; modifier=0.5;
# 	gradient=(R_E=-0.8730; p_A=-0.4878; )
# 	change  =(R_E= 1.047563e-06; p_A= 9.755502e+02; )
# 11. step; last_best= 1.07676e+03; absolute_best= 1.07676e+03; step_size= 0.01000
# 	point   =(R_E= 3.032034e-05; p_A=-1.694102e+05; )
# 	output  =1069.9569704689977; success=True; modifier=1.0;
# 	gradient=(R_E=-0.3150; p_A= 0.9491; )
# 	change  =(R_E= 3.779683e-07; p_A=-1.898201e+03; )
# 12. step; last_best= 1.06994e+03; absolute_best= 1.06994e+03; step_size= 0.01000
# 	point   =(R_E= 3.069831e-05; p_A=-1.713084e+05; )
# 	output  =1064.7716205956185; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9654; p_A=-0.2607; )
# 	change  =(R_E= 5.792494e-07; p_A= 2.607158e+02; )
# 13. step; last_best= 1.06477e+03; absolute_best= 1.06477e+03; step_size= 0.00500
# 	point   =(R_E= 3.127756e-05; p_A=-1.710477e+05; )
# 	output  =1059.180516364909; success=True; modifier=2.0;
# 	gradient=(R_E=-0.3500; p_A= 0.9367; )
# 	change  =(R_E= 4.200058e-07; p_A=-1.873496e+03; )
# 14. step; last_best= 1.05916e+03; absolute_best= 1.05916e+03; step_size= 0.01000
# 	point   =(R_E= 3.169756e-05; p_A=-1.729212e+05; )
# 	output  =1054.928270091239; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9567; p_A=-0.2910; )
# 	change  =(R_E= 5.740310e-07; p_A= 2.910156e+02; )
# 15. step; last_best= 1.05493e+03; absolute_best= 1.05493e+03; step_size= 0.00500
# 	point   =(R_E= 3.227160e-05; p_A=-1.726302e+05; )
# 	output  =1051.9731560400305; success=True; modifier=1.0;
# 	gradient=(R_E=-0.2160; p_A= 0.9764; )
# 	change  =(R_E= 1.295866e-07; p_A=-9.763983e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 16. step; last_best= 1.05195e+03; absolute_best= 1.05195e+03; step_size= 0.00500
# 	point   =(R_E= 3.240118e-05; p_A=-1.736066e+05; )
# 	output  =1049.5093847437658; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9999; p_A= 0.0141; )
# 	change  =(R_E= 5.999407e-07; p_A=-1.405714e+01; )
# 17. step; last_best= 1.04951e+03; absolute_best= 1.04951e+03; step_size= 0.00500
# 	point   =(R_E= 3.300112e-05; p_A=-1.736207e+05; )
# 	output  =1047.2395413036743; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0851; p_A= 0.9964; )
# 	change  =(R_E=-5.108796e-08; p_A=-9.963684e+02; )
# 18. step; last_best= 1.04723e+03; absolute_best= 1.04723e+03; step_size= 0.00500
# 	point   =(R_E= 3.295003e-05; p_A=-1.746170e+05; )
# 	output  =1045.0229840674162; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9949; p_A=-0.1010; )
# 	change  =(R_E= 5.969328e-07; p_A= 1.009849e+02; )
# 19. step; last_best= 1.04502e+03; absolute_best= 1.04502e+03; step_size= 0.00500
# 	point   =(R_E= 3.354697e-05; p_A=-1.745160e+05; )
# 	output  =1042.932197806466; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1167; p_A= 0.9932; )
# 	change  =(R_E=-7.003927e-08; p_A=-9.931634e+02; )
# 20. step; last_best= 1.04292e+03; absolute_best= 1.04292e+03; step_size= 0.00500
# 	point   =(R_E= 3.347693e-05; p_A=-1.755092e+05; )
# 	output  =1040.8341078457956; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9934; p_A=-0.1149; )
# 	change  =(R_E= 5.960242e-07; p_A= 1.149298e+02; )
# 21. step; last_best= 1.04083e+03; absolute_best= 1.04083e+03; step_size= 0.00500
# 	point   =(R_E= 3.407295e-05; p_A=-1.753943e+05; )
# 	output  =1038.8755610275273; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1331; p_A= 0.9911; )
# 	change  =(R_E=-7.983841e-08; p_A=-9.911074e+02; )
# 22. step; last_best= 1.03886e+03; absolute_best= 1.03886e+03; step_size= 0.00500
# 	point   =(R_E= 3.399311e-05; p_A=-1.763854e+05; )
# 	output  =1036.8693430295375; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9914; p_A=-0.1308; )
# 	change  =(R_E= 5.948414e-07; p_A= 1.308487e+02; )
# 23. step; last_best= 1.03687e+03; absolute_best= 1.03687e+03; step_size= 0.00500
# 	point   =(R_E= 3.458796e-05; p_A=-1.762545e+05; )
# 	output  =1034.9486406550272; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1402; p_A= 0.9901; )
# 	change  =(R_E=-8.412409e-08; p_A=-9.901222e+02; )
# 24. step; last_best= 1.03494e+03; absolute_best= 1.03494e+03; step_size= 0.00500
# 	point   =(R_E= 3.450383e-05; p_A=-1.772447e+05; )
# 	output  =1032.93608982532; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9925; p_A=-0.1226; )
# 	change  =(R_E= 5.954709e-07; p_A= 1.226377e+02; )
# 25. step; last_best= 1.03294e+03; absolute_best= 1.03294e+03; step_size= 0.00500
# 	point   =(R_E= 3.509930e-05; p_A=-1.771220e+05; )
# 	output  =1030.9841342022921; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1263; p_A= 0.9920; )
# 	change  =(R_E=-7.579471e-08; p_A=-9.919890e+02; )
# 26. step; last_best= 1.03097e+03; absolute_best= 1.03097e+03; step_size= 0.00500
# 	point   =(R_E= 3.502351e-05; p_A=-1.781140e+05; )
# 	output  =1028.9359303766455; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9944; p_A=-0.1057; )
# 	change  =(R_E= 5.966384e-07; p_A= 1.057067e+02; )
# 27. step; last_best= 1.02894e+03; absolute_best= 1.02894e+03; step_size= 0.00500
# 	point   =(R_E= 3.562015e-05; p_A=-1.780083e+05; )
# 	output  =1026.7749552909681; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0810; p_A= 0.9967; )
# 	change  =(R_E=-4.860164e-08; p_A=-9.967139e+02; )
# 28. step; last_best= 1.02677e+03; absolute_best= 1.02677e+03; step_size= 0.00500
# 	point   =(R_E= 3.557154e-05; p_A=-1.790050e+05; )
# 	output  =1024.7024236769162; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9978; p_A=-0.0670; )
# 	change  =(R_E= 5.986505e-07; p_A= 6.703284e+01; )
# 29. step; last_best= 1.02470e+03; absolute_best= 1.02470e+03; step_size= 0.00500
# 	point   =(R_E= 3.617020e-05; p_A=-1.789380e+05; )
# 	output  =1022.5154674327571; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0867; p_A= 0.9962; )
# 	change  =(R_E=-5.200164e-08; p_A=-9.962371e+02; )
# 30. step; last_best= 1.02251e+03; absolute_best= 1.02251e+03; step_size= 0.00500
# 	point   =(R_E= 3.611819e-05; p_A=-1.799342e+05; )
# 	output  =1020.2149935095719; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9993; p_A=-0.0362; )
# 	change  =(R_E= 5.996071e-07; p_A= 3.618493e+01; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 31. step; last_best= 1.02021e+03; absolute_best= 1.02021e+03; step_size= 0.00500
# 	point   =(R_E= 3.671780e-05; p_A=-1.798980e+05; )
# 	output  =1017.8596019241194; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0353; p_A= 0.9994; )
# 	change  =(R_E=-2.117168e-08; p_A=-9.993773e+02; )
# 32. step; last_best= 1.01785e+03; absolute_best= 1.01785e+03; step_size= 0.00500
# 	point   =(R_E= 3.669663e-05; p_A=-1.808974e+05; )
# 	output  =1015.3254021120786; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9999; p_A= 0.0106; )
# 	change  =(R_E= 5.999665e-07; p_A=-1.056903e+01; )
# 33. step; last_best= 1.01533e+03; absolute_best= 1.01533e+03; step_size= 0.00500
# 	point   =(R_E= 3.729660e-05; p_A=-1.809080e+05; )
# 	output  =1012.6551802748116; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0323; p_A= 0.9995; )
# 	change  =(R_E= 1.938545e-08; p_A=-9.994779e+02; )
# 34. step; last_best= 1.01265e+03; absolute_best= 1.01265e+03; step_size= 0.00500
# 	point   =(R_E= 3.731598e-05; p_A=-1.819075e+05; )
# 	output  =1009.7746259105762; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9956; p_A= 0.0932; )
# 	change  =(R_E= 5.973886e-07; p_A=-9.319657e+01; )
# 35. step; last_best= 1.00977e+03; absolute_best= 1.00977e+03; step_size= 0.00500
# 	point   =(R_E= 3.791337e-05; p_A=-1.820007e+05; )
# 	output  =1006.7667291069835; success=True; modifier=1.0;
# 	gradient=(R_E=-0.1087; p_A= 0.9941; )
# 	change  =(R_E= 6.524357e-08; p_A=-9.940703e+02; )
# 36. step; last_best= 1.00676e+03; absolute_best= 1.00676e+03; step_size= 0.00500
# 	point   =(R_E= 3.797861e-05; p_A=-1.829947e+05; )
# 	output  =1003.091381745058; success=True; modifier=2.0;
# 	gradient=(R_E=-0.9845; p_A= 0.1755; )
# 	change  =(R_E= 1.181373e-06; p_A=-3.510240e+02; )
# 37. step; last_best= 1.00309e+03; absolute_best= 1.00309e+03; step_size= 0.01000
# 	point   =(R_E= 3.915999e-05; p_A=-1.833457e+05; )
# 	output  =997.8158908332157; success=True; modifier=0.5;
# 	gradient=(R_E= 0.2948; p_A= 0.9556; )
# 	change  =(R_E=-1.768719e-07; p_A=-9.555631e+02; )
# 38. step; last_best= 9.97810e+02; absolute_best= 9.97810e+02; step_size= 0.00500
# 	point   =(R_E= 3.898311e-05; p_A=-1.843013e+05; )
# 	output  =980.3242487697968; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7336; p_A= 0.6796; )
# 	change  =(R_E= 1.760602e-06; p_A=-2.718394e+03; )
# 39. step; last_best= 9.80321e+02; absolute_best= 9.80321e+02; step_size= 0.02000
# 	point   =(R_E= 4.074372e-05; p_A=-1.870197e+05; )
# 	output  =970.8986769988322; success=True; modifier=1.0;
# 	gradient=(R_E=-0.3557; p_A= 0.9346; )
# 	change  =(R_E= 8.535731e-07; p_A=-3.738469e+03; )
# 40. step; last_best= 9.70879e+02; absolute_best= 9.70879e+02; step_size= 0.02000
# 	point   =(R_E= 4.159729e-05; p_A=-1.907582e+05; )
# 	output  =963.3174080745515; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9425; p_A=-0.3341; )
# 	change  =(R_E= 1.131055e-06; p_A= 6.681532e+02; )
# 41. step; last_best= 9.63317e+02; absolute_best= 9.63317e+02; step_size= 0.01000
# 	point   =(R_E= 4.272834e-05; p_A=-1.900900e+05; )
# 	output  =959.8082780431204; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1695; p_A= 0.9855; )
# 	change  =(R_E=-1.016788e-07; p_A=-9.855363e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 42. step; last_best= 9.59794e+02; absolute_best= 9.59794e+02; step_size= 0.00500
# 	point   =(R_E= 4.262667e-05; p_A=-1.910756e+05; )
# 	output  =954.084575202759; success=True; modifier=4.0;
# 	gradient=(R_E=-0.8958; p_A= 0.4444; )
# 	change  =(R_E= 2.150015e-06; p_A=-1.777510e+03; )
# 43. step; last_best= 9.54085e+02; absolute_best= 9.54085e+02; step_size= 0.02000
# 	point   =(R_E= 4.477668e-05; p_A=-1.928531e+05; )
# 	output  =946.9794847729268; success=True; modifier=0.5;
# 	gradient=(R_E= 0.5322; p_A= 0.8466; )
# 	change  =(R_E=-6.386490e-07; p_A=-1.693228e+03; )
# 44. step; last_best= 9.46969e+02; absolute_best= 9.46969e+02; step_size= 0.01000
# 	point   =(R_E= 4.413803e-05; p_A=-1.945463e+05; )
# 	output  =944.300678057032; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9949; p_A=-0.1013; )
# 	change  =(R_E= 5.969160e-07; p_A= 1.012600e+02; )
# 45. step; last_best= 9.44300e+02; absolute_best= 9.44300e+02; step_size= 0.00500
# 	point   =(R_E= 4.473495e-05; p_A=-1.944450e+05; )
# 	output  =941.7623025869899; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1627; p_A= 0.9867; )
# 	change  =(R_E= 1.951834e-07; p_A=-1.973367e+03; )
# 46. step; last_best= 9.41751e+02; absolute_best= 9.41751e+02; step_size= 0.01000
# 	point   =(R_E= 4.493013e-05; p_A=-1.964184e+05; )
# 	output  =938.4990856653977; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9641; p_A=-0.2656; )
# 	change  =(R_E= 5.784554e-07; p_A= 2.655671e+02; )
# 47. step; last_best= 9.38497e+02; absolute_best= 9.38497e+02; step_size= 0.00500
# 	point   =(R_E= 4.550859e-05; p_A=-1.961528e+05; )
# 	output  =933.3530466870181; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4052; p_A= 0.9142; )
# 	change  =(R_E= 9.724938e-07; p_A=-3.656902e+03; )
# 48. step; last_best= 9.33340e+02; absolute_best= 9.33340e+02; step_size= 0.02000
# 	point   =(R_E= 4.648108e-05; p_A=-1.998097e+05; )
# 	output  =929.492553225348; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9217; p_A=-0.3879; )
# 	change  =(R_E= 5.530173e-07; p_A= 3.879143e+02; )
# 49. step; last_best= 9.29490e+02; absolute_best= 9.29490e+02; step_size= 0.00500
# 	point   =(R_E= 4.703410e-05; p_A=-1.994218e+05; )
# 	output  =924.3371872928229; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7545; p_A= 0.6563; )
# 	change  =(R_E= 1.810709e-06; p_A=-2.625375e+03; )
# 50. step; last_best= 9.24337e+02; absolute_best= 9.24337e+02; step_size= 0.02000
# 	point   =(R_E= 4.884481e-05; p_A=-2.020472e+05; )
# 	output  =922.9954596731205; success=True; modifier=0.25;
# 	gradient=(R_E= 0.5306; p_A= 0.8476; )
# 	change  =(R_E=-3.183547e-07; p_A=-8.476279e+02; )
# 51. step; last_best= 9.22991e+02; absolute_best= 9.22991e+02; step_size= 0.00500
# 	point   =(R_E= 4.852645e-05; p_A=-2.028948e+05; )
# 	output  =922.3228241632635; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9953; p_A=-0.0967; )
# 	change  =(R_E= 2.985932e-07; p_A= 4.836576e+01; )
# 52. step; last_best= 9.22322e+02; absolute_best= 9.22322e+02; step_size= 0.00250
# 	point   =(R_E= 4.882504e-05; p_A=-2.028465e+05; )
# 	output  =921.4735465720813; success=True; modifier=2.0;
# 	gradient=(R_E=-0.2500; p_A= 0.9682; )
# 	change  =(R_E= 1.500001e-07; p_A=-9.682458e+02; )
# 53. step; last_best= 9.21469e+02; absolute_best= 9.21469e+02; step_size= 0.00500
# 	point   =(R_E= 4.897504e-05; p_A=-2.038147e+05; )
# 	output  =920.8679998065646; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9931; p_A=-0.1169; )
# 	change  =(R_E= 2.979427e-07; p_A= 5.845595e+01; )
# 54. step; last_best= 9.20868e+02; absolute_best= 9.20868e+02; step_size= 0.00250
# 	point   =(R_E= 4.927299e-05; p_A=-2.037562e+05; )
# 	output  =920.3009187692908; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1651; p_A= 0.9863; )
# 	change  =(R_E= 9.906301e-08; p_A=-9.862760e+02; )
# 55. step; last_best= 9.20300e+02; absolute_best= 9.20300e+02; step_size= 0.00500
# 	point   =(R_E= 4.937205e-05; p_A=-2.047425e+05; )
# 	output  =920.2924627559445; success=True; modifier=0.25;
# 	gradient=(R_E=-0.2969; p_A= 0.9549; )
# 	change  =(R_E= 4.452939e-08; p_A=-2.387301e+02; )
# 56. step; last_best= 9.20287e+02; absolute_best= 9.20287e+02; step_size= 0.00125
# 	point   =(R_E= 4.941658e-05; p_A=-2.049813e+05; )
# 	output  =919.4216764251113; success=True; modifier=2.0;
# 	gradient=(R_E=-0.9462; p_A=-0.3236; )
# 	change  =(R_E= 2.838593e-07; p_A= 1.617944e+02; )
# 57. step; last_best= 9.19420e+02; absolute_best= 9.19420e+02; step_size= 0.00250
# 	point   =(R_E= 4.970044e-05; p_A=-2.048195e+05; )
# 	output  =917.5538208696208; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6459; p_A= 0.7634; )
# 	change  =(R_E= 7.750957e-07; p_A=-1.526822e+03; )
# 58. step; last_best= 9.17544e+02; absolute_best= 9.17544e+02; step_size= 0.01000
# 	point   =(R_E= 5.047553e-05; p_A=-2.063463e+05; )
# 	output  =918.4669695547138; success=True; modifier=0.25;
# 	gradient=(R_E=-0.7955; p_A=-0.6059; )
# 	change  =(R_E= 2.386539e-07; p_A= 3.029683e+02; )
# 59. step; last_best= 9.18467e+02; absolute_best= 9.17544e+02; step_size= 0.00250
# 	point   =(R_E= 5.071419e-05; p_A=-2.060433e+05; )
# 	output  =917.441093429999; success=True; modifier=1.0;
# 	gradient=(R_E= 0.6111; p_A= 0.7915; )
# 	change  =(R_E=-1.833443e-07; p_A=-3.957583e+02; )
# 60. step; last_best= 9.17441e+02; absolute_best= 9.17441e+02; step_size= 0.00250
# 	point   =(R_E= 5.053084e-05; p_A=-2.064391e+05; )
# 	output  =917.1416615143088; success=True; modifier=1.0;
# 	gradient=(R_E=-0.1855; p_A= 0.9826; )
# 	change  =(R_E= 5.565514e-08; p_A=-4.913205e+02; )
# 61. step; last_best= 9.17139e+02; absolute_best= 9.17139e+02; step_size= 0.00250
# 	point   =(R_E= 5.058650e-05; p_A=-2.069304e+05; )
# 	output  =916.9473335871813; success=True; modifier=0.5;
# 	gradient=(R_E=-1.0000; p_A=-0.0036; )
# 	change  =(R_E= 1.499991e-07; p_A= 8.887731e-01; )
# 62. step; last_best= 9.16947e+02; absolute_best= 9.16947e+02; step_size= 0.00125
# 	point   =(R_E= 5.073650e-05; p_A=-2.069295e+05; )
# 	output  =916.3485009114445; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4108; p_A= 0.9117; )
# 	change  =(R_E= 2.464934e-07; p_A=-9.117155e+02; )
# 63. step; last_best= 9.16346e+02; absolute_best= 9.16346e+02; step_size= 0.00500
# 	point   =(R_E= 5.098299e-05; p_A=-2.078412e+05; )
# 	output  =916.1371445129278; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9930; p_A=-0.1178; )
# 	change  =(R_E= 1.489560e-07; p_A= 2.944394e+01; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 64. step; last_best= 9.16136e+02; absolute_best= 9.16136e+02; step_size= 0.00125
# 	point   =(R_E= 5.113195e-05; p_A=-2.078118e+05; )
# 	output  =915.5245856140991; success=True; modifier=4.0;
# 	gradient=(R_E=-0.5275; p_A= 0.8495; )
# 	change  =(R_E= 3.165173e-07; p_A=-8.495372e+02; )
# 65. step; last_best= 9.15523e+02; absolute_best= 9.15523e+02; step_size= 0.00500
# 	point   =(R_E= 5.144846e-05; p_A=-2.086613e+05; )
# 	output  =915.4052021702383; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9886; p_A= 0.1508; )
# 	change  =(R_E= 1.482841e-07; p_A=-3.770627e+01; )
# 66. step; last_best= 9.15405e+02; absolute_best= 9.15405e+02; step_size= 0.00125
# 	point   =(R_E= 5.159675e-05; p_A=-2.086990e+05; )
# 	output  =915.2899150887787; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0151; p_A= 0.9999; )
# 	change  =(R_E= 2.263375e-09; p_A=-2.499715e+02; )
# 67. step; last_best= 9.15289e+02; absolute_best= 9.15289e+02; step_size= 0.00125
# 	point   =(R_E= 5.159901e-05; p_A=-2.089490e+05; )
# 	output  =915.1752240932001; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9630; p_A= 0.2694; )
# 	change  =(R_E= 1.444530e-07; p_A=-6.735776e+01; )
# 68. step; last_best= 9.15175e+02; absolute_best= 9.15175e+02; step_size= 0.00125
# 	point   =(R_E= 5.174347e-05; p_A=-2.090163e+05; )
# 	output  =915.0696628890164; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0032; p_A= 1.0000; )
# 	change  =(R_E= 4.869341e-10; p_A=-2.499987e+02; )
# 69. step; last_best= 9.15068e+02; absolute_best= 9.15068e+02; step_size= 0.00125
# 	point   =(R_E= 5.174395e-05; p_A=-2.092663e+05; )
# 	output  =915.0127816848309; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9996; p_A=-0.0267; )
# 	change  =(R_E= 7.497320e-08; p_A= 3.341387e+00; )
# 70. step; last_best= 9.15012e+02; absolute_best= 9.15012e+02; step_size= 0.00063
# 	point   =(R_E= 5.181893e-05; p_A=-2.092630e+05; )
# 	output  =914.774806225754; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4476; p_A= 0.8942; )
# 	change  =(R_E= 1.342843e-07; p_A=-4.471134e+02; )
# 71. step; last_best= 9.14774e+02; absolute_best= 9.14774e+02; step_size= 0.00250
# 	point   =(R_E= 5.195321e-05; p_A=-2.097101e+05; )
# 	output  =914.6934237264613; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9863; p_A= 0.1648; )
# 	change  =(R_E= 1.479481e-07; p_A=-4.120961e+01; )
# 72. step; last_best= 9.14693e+02; absolute_best= 9.14693e+02; step_size= 0.00125
# 	point   =(R_E= 5.210116e-05; p_A=-2.097513e+05; )
# 	output  =914.6103521333853; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1665; p_A= 0.9860; )
# 	change  =(R_E=-2.497105e-08; p_A=-2.465115e+02; )
# 73. step; last_best= 9.14609e+02; absolute_best= 9.14609e+02; step_size= 0.00125
# 	point   =(R_E= 5.207619e-05; p_A=-2.099978e+05; )
# 	output  =914.5346268735262; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9967; p_A= 0.0810; )
# 	change  =(R_E= 1.495069e-07; p_A=-2.025484e+01; )
# 74. step; last_best= 9.14535e+02; absolute_best= 9.14535e+02; step_size= 0.00125
# 	point   =(R_E= 5.222569e-05; p_A=-2.100181e+05; )
# 	output  =914.4829651046313; success=True; modifier=0.5;
# 	gradient=(R_E= 0.4159; p_A= 0.9094; )
# 	change  =(R_E=-3.119159e-08; p_A=-1.136770e+02; )
# 75. step; last_best= 9.14482e+02; absolute_best= 9.14482e+02; step_size= 0.00063
# 	point   =(R_E= 5.219450e-05; p_A=-2.101318e+05; )
# 	output  =914.28685932734; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7529; p_A= 0.6581; )
# 	change  =(R_E= 2.258823e-07; p_A=-3.290440e+02; )
# 76. step; last_best= 9.14287e+02; absolute_best= 9.14287e+02; step_size= 0.00250
# 	point   =(R_E= 5.242038e-05; p_A=-2.104608e+05; )
# 	output  =914.2310039348843; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1880; p_A= 0.9822; )
# 	change  =(R_E=-2.820734e-08; p_A=-2.455399e+02; )
# 77. step; last_best= 9.14230e+02; absolute_best= 9.14230e+02; step_size= 0.00125
# 	point   =(R_E= 5.239218e-05; p_A=-2.107064e+05; )
# 	output  =914.167684504178; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9995; p_A=-0.0330; )
# 	change  =(R_E= 1.499182e-07; p_A= 8.257704e+00; )
# 78. step; last_best= 9.14168e+02; absolute_best= 9.14168e+02; step_size= 0.00125
# 	point   =(R_E= 5.254209e-05; p_A=-2.106981e+05; )
# 	output  =914.1115112555506; success=True; modifier=0.5;
# 	gradient=(R_E= 0.2777; p_A= 0.9607; )
# 	change  =(R_E=-2.082630e-08; p_A=-1.200841e+02; )
# 79. step; last_best= 9.14111e+02; absolute_best= 9.14111e+02; step_size= 0.00063
# 	point   =(R_E= 5.252127e-05; p_A=-2.108182e+05; )
# 	output  =913.9243154534881; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6292; p_A= 0.7773; )
# 	change  =(R_E= 1.887522e-07; p_A=-3.886322e+02; )
# 80. step; last_best= 9.13924e+02; absolute_best= 9.13924e+02; step_size= 0.00250
# 	point   =(R_E= 5.271002e-05; p_A=-2.112068e+05; )
# 	output  =913.4965010450076; success=True; modifier=4.0;
# 	gradient=(R_E=-0.5050; p_A= 0.8631; )
# 	change  =(R_E= 6.059653e-07; p_A=-1.726273e+03; )
# 81. step; last_best= 9.13494e+02; absolute_best= 9.13494e+02; step_size= 0.01000
# 	point   =(R_E= 5.331599e-05; p_A=-2.129331e+05; )
# 	output  =913.5061579822287; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8939; p_A=-0.4483; )
# 	change  =(R_E= 2.681618e-07; p_A= 2.241604e+02; )
# 82. step; last_best= 9.13506e+02; absolute_best= 9.13494e+02; step_size= 0.00250
# 	point   =(R_E= 5.358415e-05; p_A=-2.127089e+05; )
# 	output  =913.3139000438154; success=True; modifier=0.5;
# 	gradient=(R_E= 0.6800; p_A= 0.7333; )
# 	change  =(R_E=-1.019925e-07; p_A=-1.833146e+02; )
# 83. step; last_best= 9.13314e+02; absolute_best= 9.13314e+02; step_size= 0.00125
# 	point   =(R_E= 5.348216e-05; p_A=-2.128922e+05; )
# 	output  =913.2378086871179; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4211; p_A= 0.9070; )
# 	change  =(R_E= 2.526477e-07; p_A=-9.070237e+02; )
# 84. step; last_best= 9.13236e+02; absolute_best= 9.13236e+02; step_size= 0.00500
# 	point   =(R_E= 5.373480e-05; p_A=-2.137993e+05; )
# 	output  =913.1260493903605; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8754; p_A=-0.4834; )
# 	change  =(R_E= 1.313109e-07; p_A= 1.208470e+02; )
# 85. step; last_best= 9.13126e+02; absolute_best= 9.13126e+02; step_size= 0.00125
# 	point   =(R_E= 5.386611e-05; p_A=-2.136784e+05; )
# 	output  =913.1159554450076; success=True; modifier=0.25;
# 	gradient=(R_E= 0.4181; p_A= 0.9084; )
# 	change  =(R_E=-1.567977e-08; p_A=-5.677428e+01; )
# 86. step; last_best= 9.13116e+02; absolute_best= 9.13116e+02; step_size= 0.00031
# 	point   =(R_E= 5.385043e-05; p_A=-2.137352e+05; )
# 	output  =913.0923189522807; success=True; modifier=4.0;
# 	gradient=(R_E=-0.8227; p_A= 0.5685; )
# 	change  =(R_E= 1.233981e-07; p_A=-1.421356e+02; )
# 87. step; last_best= 9.13092e+02; absolute_best= 9.13092e+02; step_size= 0.00125
# 	point   =(R_E= 5.397383e-05; p_A=-2.138773e+05; )
# 	output  =913.0768600266294; success=True; modifier=0.25;
# 	gradient=(R_E= 0.5679; p_A= 0.8231; )
# 	change  =(R_E=-2.129719e-08; p_A=-5.144252e+01; )
# 88. step; last_best= 9.13077e+02; absolute_best= 9.13077e+02; step_size= 0.00031
# 	point   =(R_E= 5.395254e-05; p_A=-2.139288e+05; )
# 	output  =913.066163446459; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1971; p_A= 0.9804; )
# 	change  =(R_E= 1.478586e-08; p_A=-1.225468e+02; )
# 89. step; last_best= 9.13066e+02; absolute_best= 9.13066e+02; step_size= 0.00063
# 	point   =(R_E= 5.396732e-05; p_A=-2.140513e+05; )
# 	output  =913.0569967343033; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9869; p_A=-0.1615; )
# 	change  =(R_E= 3.700790e-08; p_A= 1.009202e+01; )
# 90. step; last_best= 9.13057e+02; absolute_best= 9.13057e+02; step_size= 0.00031
# 	point   =(R_E= 5.400433e-05; p_A=-2.140412e+05; )
# 	output  =913.0481241484212; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1613; p_A= 0.9869; )
# 	change  =(R_E= 1.210073e-08; p_A=-1.233623e+02; )
# 91. step; last_best= 9.13048e+02; absolute_best= 9.13048e+02; step_size= 0.00063
# 	point   =(R_E= 5.401643e-05; p_A=-2.141646e+05; )
# 	output  =913.0379013616276; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9941; p_A=-0.1088; )
# 	change  =(R_E= 3.727725e-08; p_A= 6.802149e+00; )
# 92. step; last_best= 9.13038e+02; absolute_best= 9.13038e+02; step_size= 0.00031
# 	point   =(R_E= 5.405371e-05; p_A=-2.141578e+05; )
# 	output  =913.0155012382222; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4004; p_A= 0.9163; )
# 	change  =(R_E= 6.006166e-08; p_A=-2.290839e+02; )
# 93. step; last_best= 9.13015e+02; absolute_best= 9.13015e+02; step_size= 0.00125
# 	point   =(R_E= 5.411377e-05; p_A=-2.143869e+05; )
# 	output  =913.0058970403264; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9552; p_A=-0.2959; )
# 	change  =(R_E= 3.582060e-08; p_A= 1.849435e+01; )
# 94. step; last_best= 9.13006e+02; absolute_best= 9.13006e+02; step_size= 0.00031
# 	point   =(R_E= 5.414959e-05; p_A=-2.143684e+05; )
# 	output  =912.9966022688396; success=True; modifier=1.0;
# 	gradient=(R_E=-0.2197; p_A= 0.9756; )
# 	change  =(R_E= 8.237031e-09; p_A=-6.097361e+01; )
# 95. step; last_best= 9.12997e+02; absolute_best= 9.12997e+02; step_size= 0.00031
# 	point   =(R_E= 5.415783e-05; p_A=-2.144293e+05; )
# 	output  =913.0021931667453; success=True; modifier=0.25;
# 	gradient=(R_E= 0.6678; p_A= 0.7443; )
# 	change  =(R_E=-6.260683e-09; p_A=-1.163024e+01; )

# %%
all_central_points = []
central_outputs = []
for points in datas:
    outputs = [data[to_optimize] for data in points]
    central_outputs.append(outputs[0])
    #central_outputs.append(min(outputs))
    all_central_points.append(points[0])
value1 = [data[key1] for data in all_central_points]
value2 = [data[key2] for data in all_central_points]
start = len(all_central_points) // 2
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].plot(value1[:start+1], value2[:start+1], '.-', color='blue', linewidth=1, zorder=1)
ax[0].plot(value1[start:], value2[start:], '.-', color='lightblue', linewidth=0.5, zorder=1)
ax[1].plot(value1[start:], value2[start:], '.-', color='lightblue', linewidth=1, zorder=1)
ax[0].scatter([value1[0]], [value2[0]], color='green', zorder=2, s=25)   # start point
ax[0].scatter([value1[-1]], [value2[-1]], color='red', zorder=2, s=25)   # optimal point
ax[1].scatter([value1[-1]], [value2[-1]], color='red', zorder=2, s=25)   # optimal point
ax[0].text(value1[0], value2[0], f'  start: ({value1[0]:.2e}, {value2[0]:.2e})', fontsize=12)
ax[1].text(value1[-1], value2[-1], f'  end: ({value1[-1]:.2e}, {value2[-1]:.2e})', fontsize=12)
ax[0].set_title('All points')
ax[1].set_title('Near optimal point')
ax[0].set_xlabel(key1)
ax[0].set_ylabel(key2)
ax[1].set_xlabel(key1)
ax[1].set_ylabel(key2)
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(12, 5))
ax.plot(range(len(central_outputs[:])), central_outputs[:], '.-')
ax.set_ylim([0.999*min(central_outputs), 1.05*min(central_outputs)])
ax.set_xticks(range(0, len(central_outputs[:]), 10), minor=False)
ax.set_xticks(range(len(central_outputs[:])), minor=True)
ax.tick_params(which='major', axis='x', width=2, grid_color='darkgrey', grid_linewidth=1.5)
ax.set_xlabel('step number [-]')
ax.set_ylabel(to_optimize)
ax.grid(which='both')
#plt.yscale('log')
plt.show()
print(f'last output: {central_outputs[-1]: .2f}')
# Out:
# last output:  913.00

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 10))
levels = np.linspace(vmin, vmax, 250)
maxi = np.log10(max(central_outputs))
cp = ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=min(vmax, maxi), extend='max')
ax.contour(X, Y, Z, levels=np.linspace(vmin, vmax, contour_levels), colors='black', linewidths=0.5)
colorbar_title = '$Energy\ demand\ [MJ/kg_{' + gd.de.target_specie + '}]$'
cbar = fig.colorbar(cp, label=colorbar_title) # Add a colorbar to a plot

ax.plot(value1[:], value2[:], '.-', color='blue', linewidth=1, zorder=1)
ax.scatter([value1[0]], [value2[0]], color='green', zorder=2, s=25)   # start point
ax.scatter([value1[-1]], [value2[-1]], color='green', zorder=2, s=25)   # optimal point
ax.text(value1[0], value2[0], f'  start: ({value1[0]:.2e}, {value2[0]:.2e})', fontsize=12)
ax.set_title('All points')
ax.set_xlabel(key1)
ax.set_ylabel(key2)

range1 = max(value1) - min(value1)
range2 = max(value2) - min(value2)
range1 = [min(value1) - 0.05*range1, max(value1) + 0.05*range1]
range2 = [min(value2) - 0.05*range2, max(value2) + 0.05*range2]
ax.set_xlim(range1)
ax.set_ylim(range2)

ticks = cbar.get_ticks()
cbar.set_ticks(ticks)
if use_log10:
    cbar.set_ticklabels([f'{10**tick:.0f}' for tick in ticks])  # Format as powers of 10
else:
    cbar.set_ticklabels([f'{tick:.1f}' for tick in ticks])
cbar.ax.tick_params(labelsize=12)  # Adjust font size
plt.show()
