# %% [markdown]
# ## Importing libraries, parameters.py

# %%
"""Create parameters.py and load it"""

# Directory for .inp file:
path = 'INP file examples\\chem_Otomo2018_without_O.inp'

# import libraries:
import importlib   # For reloading your own files
from termcolor import colored   # for colored error messages

# import inp_data_extractor.py as inp:
try:
    import inp_data_extractor as inp
except ImportError:
    try:
        from Bubble_dynamics_simulation import inp_data_extractor as inp
    except ImportError as error:
        print(colored(f'Error, \'inp_data_extractor.py\' not found', 'red'))
        raise error
    except Exception as error:
        print(colored(f'Error, \'inp_data_extractor.py\' failed to load', 'red'))
        raise error
except Exception as error:
    print(colored(f'Error, \'inp_data_extractor.py\' failed to load', 'red'))
    raise error
importlib.reload(inp)   # reload changes you made

# create parameters.py
inp.extract(path)

import parameters as par   # numeric constants and coefficents
importlib.reload(par)   # reload changes you made
print(par.model)
# Out:
# path=INP file examples\chem_Otomo2018_without_O.inp
# Note, lambda value for specie 'H' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NH2' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NH' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NNH' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H4' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H3' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H2' is not in data.py: 0.0 is used
# Note, lambda value for specie 'H2NN' is not in data.py: 0.0 is used
# Warning, third body 'H2O' is not in species in line 64 (' H2/2.5/ H2O/12/ AR/0.0/ ') in reaction 'H2+M=H+H+M'
# Warning, third body 'AR' is not in species in line 64 (' H2/2.5/ H2O/12/ AR/0.0/ ') in reaction 'H2+M=H+H+M'
# model: chem_Otomo2018_without_O
# File 'parameters.py' succesfully created
# chem_Otomo2018_without_O

# %%
"""Libraries"""

# for plotting:
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

import numpy as np   # matrices, math
import time   # runtime measurement
import os    # file management
import pandas as pd   # data frames
from multiprocessing import Pool, cpu_count   # multithreading
import importlib   # reload changes you made

# import gradient_descent.py as gd:
_already_imported = 'gd' in globals()
try:
    import gradient_descent as gd
except ImportError:
    try:
        from  Bubble_dynamics_simulation import gradient_descent as gd
    except ImportError as _error:
        print(colored(f'Error, \'gradient_descent.py\' not found', 'red'))
        raise _error
    except Exception as _error:
        print(colored(f'Error, \'gradient_descent.py\' failed to load', 'red'))
        raise _error
except Exception as _error:
    print(colored(f'Error, \'gradient_descent.py\' failed to load', 'red'))
    raise _error
if _already_imported: importlib.reload(gd)   # reload changes you made
# Out:
# model: chem_Otomo2018_without_O
# target specie: NH3
# excitation: sin_impulse (control parameters: ['p_A', 'freq', 'n'])
# enable heat transfer: True	enable evaporation: False	enable reactions: True	enable dissipated energy: True

# %% [markdown]
# ## Ranges, settings

# %%
# Control parameter ranges
# make sure, it's only 2D

ranges = dict(
  # Initial conditions:
    # bubble equilibrium radius [m]
    R_E = [1e-6*x for x in [5.0, 125.0]], # [um --> m]
    # initial radius / equilibrium radius R_0/R_E [-]
    ratio = [1.0],
    # indexes of species in initial bubble
    gases=[[par.index['N2'], par.index['H2']]],
    # Molar fractions of species in the initial bubble (H2 and N2) [-]
    fractions=[[0.25, 0.75]],
  # Ambient parameters:
    # ambient pressure [Pa]
    P_amb = [x * par.atm2Pa for x in [1.0]], # [atm --> Pa]
    # ambient temperature [K]       
    T_inf = [par.absolute_zero + x for x in [20.0]], # [°C --> K]
  # Liquid parameters:
    # water accommodation coefficient [-]
    alfa_M = [0.35],
    # vapour pressure [Pa]
    #P_v = par.P_v, # calculated from T_inf
    # dynamic viscosity [Pa*s]
    #mu_L = par.mu_L, # calculated from T_inf
    # density [kg/m^3]
    rho_L =  [998.20],
    # sound speed [m/s]
    c_L = [par.c_L],
    # surfactant (surface tension modfier) [-]
    surfactant = [1.0],
  # Excitation parameters: (excitation_type = sin_impulse)
    # excitation amplitude [Pa]
    p_A = [-x * par.bar2Pa for x in [1.0, 3.0]], # [bar --> Pa]
    # excitation frequency [Hz]
    freq =  [20000.00],
    # excitation duration in period times [-]
    n =  [1.00],
)

for key in gd.de.excitation_args:
    if key not in ranges:
        print(colored(f'Error, {key} not in ranges', 'red'))

examined_keys = []
for key in ranges:
    if len(ranges[key]) > 1:
        examined_keys.append(key)

print(f'The following control parameters will be examined: {examined_keys}')
if len(examined_keys) != 2:
    print(colored(f'Error, exactly 2 control parameters have to be examined', 'red'))
key1 = examined_keys[0]
key2 = examined_keys[1]
# Out:
# The following control parameters will be examined: ['R_E', 'p_A']

# %%
# Settings:
to_optimize = 'energy_demand'   # key in data from de.get_data()
directory = 'test_1atm_20000Hz_2D'   # appropiate 2D bruteforce parameter study
file_base_name = 'output_'

# %% [markdown]
# ## Reading files, 2D contour plot
# This is optional, you don't have to place a contour plot underneath the gadient descent visualization.
# The bruteforce param study should be 2D with the same range as above, and uniform spacement.

# %%
# create a dataframe
all_data = pd.DataFrame()
num = 0

# iterate trough all files in directory (including subdirectories)
for (root, dirs, files) in os.walk(directory):
    for file in files:
        # ignore python rubish
        if 'ipynb_checkpoints' in root:
            continue
        # check if it's a CSV starting with file_base_name
        if file[-4:] != '.csv':
            continue
        if file[:len(file_base_name)] != file_base_name:
            continue

        # read file
        num += 1
        current_data = pd.read_csv(os.path.join(root, file))

        # Cast object-dtype columns with all-bool values to bool dtype
        for col in current_data.columns:
            if current_data[col].dtype == 'object' and all(current_data[col].dropna().map(lambda x: isinstance(x, bool))):
                current_data[col] = current_data[col].astype(bool)

                
        print(f'\t{file: <24} ({current_data.shape[0]: >4} rows)')
        all_data = pd.concat([all_data, current_data])

# locate successful simulations (or use all_data['success'] == True)
good_data = all_data.loc[
    (all_data['error_code'] % 100 <= 3) & ((all_data['error_code'] // 100) % 10 != 1) &
    (all_data['energy_demand'] > 0.0) & (all_data['energy_demand'] == all_data['energy_demand']) # positive not NaN
]

good_data = good_data.sort_values(['ID'], ascending=True)
print(f'Good data: {good_data.shape[0]} rows ({100*good_data.shape[0]/all_data.shape[0]: .2f} %)')
# Out:
# 	output_1.csv             (1001 rows)
# 	output_2.csv             (1001 rows)
# 	output_3.csv             ( 498 rows)
# Good data: 2424 rows ( 96.96 %)

# %%
# Check ranges vs good_data:
for key in ranges:
    llist = good_data[key].unique()
    llist.sort()
    if len(llist) > 1 and len(ranges[key]) < 2:
        print(colored(f'Error, {key} has {len(llist)} distinct values, but it should be constant {ranges[key][0]}', 'red'))
    if len(ranges[key]) > 1:
        if len(llist) < 2:
            print(colored(f'Error, {key} should have  values between {ranges[key][0]} and {ranges[key][1]}', 'red'))
        if abs(llist[0] - min(ranges[key])) / abs(min(ranges[key]) + 1e-10) > 1e-5:
            print(colored(f'Error, {key} has values between {llist[0]} and {llist[-1]}, but it should be between {ranges[key][0]} and {ranges[key][1]}', 'red'))
        if abs(llist[-1] - max(ranges[key])) / abs(max(ranges[key]) + 1e-10) > 1e-5:
            print(colored(f'Error, {key} has values between {llist[0]} and {llist[-1]}, but it should be between {ranges[key][0]} and {ranges[key][1]}', 'red'))

# %%
# list unique values:

output_list = list(good_data[to_optimize])
list1 = list(good_data[key1])
list2 = list(good_data[key2])
value_list1 = good_data[key1].unique()
value_list2 = good_data[key2].unique()
value_list1.sort()
value_list2.sort()
print(f'{key1}: from {value_list1[0]} to {value_list1[-1]} ({len(value_list1)} values)')
print(f'{key2}: from {value_list2[0]} to {value_list2[-1]} ({len(value_list2)} values)')
# Out:
# R_E: from 5e-06 to 0.000125 (50 values)
# p_A: from -300000.0 to -100000.0 (50 values)

# %%
# Interpolate missing values
# Settings:
catch_outliers = True
use_log10 = True
fix_missing_values = True

# Assemble meshgrid, and existing data points:
combined = []   # (key1, key2) pairs in order
output_list = []    # values of to_optimize in the sameorder
for x in value_list1:
    for y in value_list2:
        energy = good_data.loc[(good_data[key1] == x) & (good_data[key2] == y), to_optimize]
        if len(energy) == 1:
            energy = energy.values[0]
            combined.append((x, y))
            output_list.append(energy)
            
if use_log10:
    output_list = list(np.log10(output_list))
vmin = min(output_list) # min
vmax = 2.0*vmin if use_log10 else 100.0*vmin    # max
X, Y = np.meshgrid(value_list1, value_list2)
Z = np.zeros(X.shape)
fixed = 0

# Iterate trough all possible combinations:
for i, x in enumerate(value_list1):
    for j, y in enumerate(value_list2):
        if (x, y) not in combined:  # missing values
            index = i * len(value_list2) + j
            y1 = combined[index-1][1]; y2 = combined[index][1]
            o1 = output_list[index-1]; o2 = output_list[index]
            if abs(y2 - y1) > 0.3*abs(value_list2[-1] - value_list2[0]):
                # if the gap of missing values is too large
                extrapolation = 30.0 if use_log10 else 1e30
            else:
                # linear interpolation
                extrapolation = o1 + (o2 - o1) * (y - y1) / (y2 - y1)

            combined = combined[:index] + [(x, y)] + combined[index:]
            if fix_missing_values:
                output_list = output_list[:index] + [extrapolation] + output_list[index:]
            else:
                output_list = output_list[:index] + [vmax] + output_list[index:]
            Z[j, i] = output_list[index]
            fixed += 1

        else: # outliers
            index = combined.index((x, y))
            big = 2.0 if use_log10 else 100000.0 # ratio of outlier and neigbouring value

            if (i != 0 and i != len(value_list1)-1 and # not on the edge
                j != 0 and j != len(value_list2)-1 and  # not on the edge
                output_list[index-1] < vmax and output_list[index+1] < vmax and    # neighbouring values are not too big
                output_list[index] > big*output_list[index+1] and    # much bigger than the next
                output_list[index] > big*output_list[index-1] and catch_outliers):   # much bigger than the previous

                output_list[index] = (output_list[index-1] + output_list[index+1]) / 2
                print(f'{index}: {key1}={x : .4e}, {key2}={y: .4e}, output={output_list[index]: .3f}')
            Z[j, i] = output_list[index]
            

print(f'{fixed} missing values fixed')
# Out:
# 76 missing values fixed

# %%
# Plot:
contour_levels = 20
title = ''
xlabel = key1
ylabel = key2

fig,ax=plt.subplots(1, 1, figsize=(12, 10))
levels = np.linspace(vmin, vmax, 250)
cp = ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=vmax, extend='max')
ax.contour(X, Y, Z, levels=np.linspace(vmin, vmax, contour_levels), colors='black', linewidths=0.5)
colorbar_title = '$Energy\ demand\ [MJ/kg_{' + gd.de.target_specie + '}]$'
cbar = fig.colorbar(cp, label=colorbar_title) # Add a colorbar to a plot
ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ticks = cbar.get_ticks()
cbar.set_ticks(ticks)
if use_log10:
    cbar.set_ticklabels([f'{10**tick:.0f}' for tick in ticks])  # Format as powers of 10
else:
    cbar.set_ticklabels([f'{tick:.1f}' for tick in ticks])
cbar.ax.tick_params(labelsize=12)  # Adjust font size
plt.show()

# %% [markdown]
# ## Plot gradient descent search

# %%
# Generate random starting_point:

start_point = gd.rand_point(ranges, padding=0.01)   # random point in ranges

print(f'Starting point: ({key1}={start_point[key1]}, {key2}={start_point[key2]})')
data, success = gd.evaluate(start_point, to_optimize, t_int=[0.0, 1.0], LSODA_timeout=10, Radau_timeout=0)
if not success:
    print(colored(f'Error, simulation failed', 'red'))
else:
    print(f'Output in starting point: {data[to_optimize]: .4f}')

# Plot:

fig,ax=plt.subplots(1, 1, figsize=(4, 4))
levels = np.linspace(vmin, vmax, 100)
ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=vmax, extend='max')
ax.scatter(start_point[key1], start_point[key2], color='black', s=100, label='Starting point')
ax.axis('off')
plt.show()
# Out:
# Starting point: (R_E=9.401581436287196e-06, p_A=-107922.94649825132)
# Output in starting point:  32420703200117133312.0000

# %%
start_point_copy = gd.de.copy(start_point)

datas, last_bests, elapsed_time = gd.gradient_descent(
    ranges=ranges, path='', to_optimize=to_optimize, start_point=start_point_copy,
    step_limit=100, first_step=0.01, min_step=1e-4, delta=1e-5,
    verbose=True, t_int=np.array([0.0, 1.0]), LSODA_timeout=10.0, Radau_timeout=0.0
)
# Out:
# 0. step; last_best= 3.24207e+19; absolute_best= 3.24207e+19; step_size= 0.01000
# 	point   =(R_E= 9.401581e-06; p_A=-1.079229e+05; )
# 	output  =6749511676071.336; success=True; modifier=4.0;
# 	gradient=(R_E= 0.7071; p_A= 0.7071; )
# 	change  =(R_E=-3.394113e-06; p_A=-5.656854e+03; )
# 1. step; last_best= 6.71569e+12; absolute_best= 6.71569e+12; step_size= 0.04000
# 	point   =(R_E= 6.007469e-06; p_A=-1.135798e+05; )
# 	output  =2207.758270554806; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4610; p_A= 0.8874; )
# 	change  =(R_E= 8.850429e-06; p_A=-2.839747e+04; )
# 2. step; last_best= 2.20776e+03; absolute_best= 2.20776e+03; step_size= 0.16000
# 	point   =(R_E= 1.485790e-05; p_A=-1.419773e+05; )
# 	output  =1709.930158946288; success=True; modifier=0.25;
# 	gradient=(R_E= 0.3914; p_A= 0.9202; )
# 	change  =(R_E=-1.878561e-06; p_A=-7.361878e+03; )
# 3. step; last_best= 1.70972e+03; absolute_best= 1.70972e+03; step_size= 0.04000
# 	point   =(R_E= 1.297934e-05; p_A=-1.493392e+05; )
# 	output  =1518.8871444208485; success=True; modifier=0.5;
# 	gradient=(R_E=-0.8158; p_A=-0.5784; )
# 	change  =(R_E= 1.957835e-06; p_A= 2.313537e+03; )
# 4. step; last_best= 1.51889e+03; absolute_best= 1.51889e+03; step_size= 0.02000
# 	point   =(R_E= 1.493717e-05; p_A=-1.470256e+05; )
# 	output  =1482.5552134241732; success=True; modifier=0.5;
# 	gradient=(R_E= 0.0445; p_A= 0.9990; )
# 	change  =(R_E=-5.343822e-08; p_A=-1.998016e+03; )
# 5. step; last_best= 1.48248e+03; absolute_best= 1.48248e+03; step_size= 0.01000
# 	point   =(R_E= 1.488373e-05; p_A=-1.490236e+05; )
# 	output  =1452.0584880945066; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9830; p_A=-0.1838; )
# 	change  =(R_E= 1.179546e-06; p_A= 3.676957e+02; )
# 6. step; last_best= 1.45205e+03; absolute_best= 1.45205e+03; step_size= 0.01000
# 	point   =(R_E= 1.606328e-05; p_A=-1.486559e+05; )
# 	output  =1423.0372258774107; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0618; p_A= 0.9981; )
# 	change  =(R_E= 7.413987e-08; p_A=-1.996179e+03; )
# 7. step; last_best= 1.42297e+03; absolute_best= 1.42297e+03; step_size= 0.01000
# 	point   =(R_E= 1.613742e-05; p_A=-1.506521e+05; )
# 	output  =1397.3471523599048; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9776; p_A=-0.2106; )
# 	change  =(R_E= 1.173090e-06; p_A= 4.211715e+02; )
# 8. step; last_best= 1.39735e+03; absolute_best= 1.39735e+03; step_size= 0.01000
# 	point   =(R_E= 1.731051e-05; p_A=-1.502309e+05; )
# 	output  =1374.752966020971; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0163; p_A= 0.9999; )
# 	change  =(R_E= 1.959867e-08; p_A=-1.999733e+03; )
# 9. step; last_best= 1.37470e+03; absolute_best= 1.37470e+03; step_size= 0.01000
# 	point   =(R_E= 1.733011e-05; p_A=-1.522307e+05; )
# 	output  =1351.8048953112043; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9674; p_A=-0.2531; )
# 	change  =(R_E= 1.160915e-06; p_A= 5.062833e+02; )
# 10. step; last_best= 1.35180e+03; absolute_best= 1.35180e+03; step_size= 0.01000
# 	point   =(R_E= 1.849102e-05; p_A=-1.517244e+05; )
# 	output  =1329.7842095377541; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0366; p_A= 0.9993; )
# 	change  =(R_E= 4.394470e-08; p_A=-1.998658e+03; )
# 11. step; last_best= 1.32973e+03; absolute_best= 1.32973e+03; step_size= 0.01000
# 	point   =(R_E= 1.853497e-05; p_A=-1.537230e+05; )
# 	output  =1310.3870067748292; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9758; p_A=-0.2185; )
# 	change  =(R_E= 1.170999e-06; p_A= 4.370394e+02; )
# 12. step; last_best= 1.31039e+03; absolute_best= 1.31039e+03; step_size= 0.01000
# 	point   =(R_E= 1.970597e-05; p_A=-1.532860e+05; )
# 	output  =1294.0842561685818; success=True; modifier=0.5;
# 	gradient=(R_E= 0.0474; p_A= 0.9989; )
# 	change  =(R_E=-2.845493e-08; p_A=-9.988748e+02; )
# 13. step; last_best= 1.29406e+03; absolute_best= 1.29406e+03; step_size= 0.00500
# 	point   =(R_E= 1.967751e-05; p_A=-1.542849e+05; )
# 	output  =1242.3367360860816; success=True; modifier=4.0;
# 	gradient=(R_E=-0.8066; p_A= 0.5910; )
# 	change  =(R_E= 1.935949e-06; p_A=-2.364142e+03; )
# 14. step; last_best= 1.24232e+03; absolute_best= 1.24232e+03; step_size= 0.02000
# 	point   =(R_E= 2.161346e-05; p_A=-1.566490e+05; )
# 	output  =1148.184587192981; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6264; p_A= 0.7795; )
# 	change  =(R_E= 6.013328e-06; p_A=-1.247218e+04; )
# 15. step; last_best= 1.14812e+03; absolute_best= 1.14812e+03; step_size= 0.08000
# 	point   =(R_E= 2.762679e-05; p_A=-1.691212e+05; )
# 	output  =1099.5243359596705; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8361; p_A=-0.5485; )
# 	change  =(R_E= 2.006702e-06; p_A= 2.194151e+03; )
# 16. step; last_best= 1.09952e+03; absolute_best= 1.09952e+03; step_size= 0.02000
# 	point   =(R_E= 2.963349e-05; p_A=-1.669271e+05; )
# 	output  =1088.1542829104658; success=True; modifier=0.25;
# 	gradient=(R_E= 0.3307; p_A= 0.9437; )
# 	change  =(R_E=-1.984306e-07; p_A=-9.437297e+02; )
# 17. step; last_best= 1.08815e+03; absolute_best= 1.08815e+03; step_size= 0.00500
# 	point   =(R_E= 2.943506e-05; p_A=-1.678708e+05; )
# 	output  =1077.901332789598; success=True; modifier=4.0;
# 	gradient=(R_E=-0.3846; p_A= 0.9231; )
# 	change  =(R_E= 9.230890e-07; p_A=-3.692299e+03; )
# 18. step; last_best= 1.07787e+03; absolute_best= 1.07787e+03; step_size= 0.02000
# 	point   =(R_E= 3.035815e-05; p_A=-1.715631e+05; )
# 	output  =1065.4085838016608; success=True; modifier=0.5;
# 	gradient=(R_E=-0.8832; p_A=-0.4689; )
# 	change  =(R_E= 1.059882e-06; p_A= 9.378602e+02; )
# 19. step; last_best= 1.06541e+03; absolute_best= 1.06541e+03; step_size= 0.01000
# 	point   =(R_E= 3.141803e-05; p_A=-1.706252e+05; )
# 	output  =1061.407247578052; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1657; p_A= 0.9862; )
# 	change  =(R_E=-9.942728e-08; p_A=-9.861742e+02; )
# 20. step; last_best= 1.06140e+03; absolute_best= 1.06140e+03; step_size= 0.00500
# 	point   =(R_E= 3.131860e-05; p_A=-1.716114e+05; )
# 	output  =1058.0303170816708; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9899; p_A= 0.1415; )
# 	change  =(R_E= 5.939663e-07; p_A=-1.414615e+02; )
# 21. step; last_best= 1.05803e+03; absolute_best= 1.05803e+03; step_size= 0.00500
# 	point   =(R_E= 3.191257e-05; p_A=-1.717529e+05; )
# 	output  =1055.0832597753554; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0541; p_A= 0.9985; )
# 	change  =(R_E= 3.246378e-08; p_A=-9.985352e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 22. step; last_best= 1.05506e+03; absolute_best= 1.05506e+03; step_size= 0.00500
# 	point   =(R_E= 3.194503e-05; p_A=-1.727514e+05; )
# 	output  =1052.3521914831088; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9999; p_A=-0.0119; )
# 	change  =(R_E= 5.999579e-07; p_A= 1.185075e+01; )
# 23. step; last_best= 1.05235e+03; absolute_best= 1.05235e+03; step_size= 0.00500
# 	point   =(R_E= 3.254499e-05; p_A=-1.727395e+05; )
# 	output  =1049.8469952690168; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0428; p_A= 0.9991; )
# 	change  =(R_E=-2.565502e-08; p_A=-9.990854e+02; )
# 24. step; last_best= 1.04984e+03; absolute_best= 1.04984e+03; step_size= 0.00500
# 	point   =(R_E= 3.251934e-05; p_A=-1.737386e+05; )
# 	output  =1047.4948070217238; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9971; p_A=-0.0756; )
# 	change  =(R_E= 5.982822e-07; p_A= 7.561607e+01; )
# 25. step; last_best= 1.04749e+03; absolute_best= 1.04749e+03; step_size= 0.00500
# 	point   =(R_E= 3.311762e-05; p_A=-1.736630e+05; )
# 	output  =1045.324946701121; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1075; p_A= 0.9942; )
# 	change  =(R_E=-6.452302e-08; p_A=-9.942009e+02; )
# 26. step; last_best= 1.04531e+03; absolute_best= 1.04531e+03; step_size= 0.00500
# 	point   =(R_E= 3.305310e-05; p_A=-1.746572e+05; )
# 	output  =1043.1577340789702; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9934; p_A=-0.1148; )
# 	change  =(R_E= 5.960311e-07; p_A= 1.148305e+02; )
# 27. step; last_best= 1.04316e+03; absolute_best= 1.04316e+03; step_size= 0.00500
# 	point   =(R_E= 3.364913e-05; p_A=-1.745424e+05; )
# 	output  =1041.140667204215; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1273; p_A= 0.9919; )
# 	change  =(R_E=-7.637893e-08; p_A=-9.918645e+02; )
# 28. step; last_best= 1.04113e+03; absolute_best= 1.04113e+03; step_size= 0.00500
# 	point   =(R_E= 3.357275e-05; p_A=-1.755342e+05; )
# 	output  =1039.0998477762053; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9916; p_A=-0.1293; )
# 	change  =(R_E= 5.949668e-07; p_A= 1.292552e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 29. step; last_best= 1.03910e+03; absolute_best= 1.03910e+03; step_size= 0.00500
# 	point   =(R_E= 3.416772e-05; p_A=-1.754050e+05; )
# 	output  =1037.1882891857435; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1433; p_A= 0.9897; )
# 	change  =(R_E=-8.596483e-08; p_A=-9.896830e+02; )
# 30. step; last_best= 1.03718e+03; absolute_best= 1.03718e+03; step_size= 0.00500
# 	point   =(R_E= 3.408175e-05; p_A=-1.763947e+05; )
# 	output  =1035.164559187551; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9917; p_A=-0.1285; )
# 	change  =(R_E= 5.950254e-07; p_A= 1.285044e+02; )
# 31. step; last_best= 1.03516e+03; absolute_best= 1.03516e+03; step_size= 0.00500
# 	point   =(R_E= 3.467678e-05; p_A=-1.762662e+05; )
# 	output  =1033.2722321982144; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1346; p_A= 0.9909; )
# 	change  =(R_E=-8.077441e-08; p_A=-9.908968e+02; )
# 32. step; last_best= 1.03326e+03; absolute_best= 1.03326e+03; step_size= 0.00500
# 	point   =(R_E= 3.459600e-05; p_A=-1.772571e+05; )
# 	output  =1031.288648676446; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9918; p_A=-0.1277; )
# 	change  =(R_E= 5.950885e-07; p_A= 1.276895e+02; )
# 33. step; last_best= 1.03129e+03; absolute_best= 1.03129e+03; step_size= 0.00500
# 	point   =(R_E= 3.519109e-05; p_A=-1.771294e+05; )
# 	output  =1029.3306543787053; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1246; p_A= 0.9922; )
# 	change  =(R_E=-7.476802e-08; p_A=-9.922054e+02; )
# 34. step; last_best= 1.02932e+03; absolute_best= 1.02932e+03; step_size= 0.00500
# 	point   =(R_E= 3.511632e-05; p_A=-1.781216e+05; )
# 	output  =1027.3249426777725; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9941; p_A=-0.1085; )
# 	change  =(R_E= 5.964569e-07; p_A= 1.085142e+02; )
# 35. step; last_best= 1.02732e+03; absolute_best= 1.02732e+03; step_size= 0.00500
# 	point   =(R_E= 3.571278e-05; p_A=-1.780131e+05; )
# 	output  =1025.2802709800226; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1083; p_A= 0.9941; )
# 	change  =(R_E=-6.497373e-08; p_A=-9.941194e+02; )
# 36. step; last_best= 1.02527e+03; absolute_best= 1.02527e+03; step_size= 0.00500
# 	point   =(R_E= 3.564781e-05; p_A=-1.790072e+05; )
# 	output  =1023.1884966447492; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9965; p_A=-0.0834; )
# 	change  =(R_E= 5.979082e-07; p_A= 8.342955e+01; )
# 37. step; last_best= 1.02319e+03; absolute_best= 1.02319e+03; step_size= 0.00500
# 	point   =(R_E= 3.624571e-05; p_A=-1.789238e+05; )
# 	output  =1021.0111021900698; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0812; p_A= 0.9967; )
# 	change  =(R_E=-4.871395e-08; p_A=-9.966986e+02; )
# 38. step; last_best= 1.02100e+03; absolute_best= 1.02100e+03; step_size= 0.00500
# 	point   =(R_E= 3.619700e-05; p_A=-1.799205e+05; )
# 	output  =1018.6995775835514; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9994; p_A=-0.0341; )
# 	change  =(R_E= 5.996512e-07; p_A= 3.409105e+01; )
# 39. step; last_best= 1.01870e+03; absolute_best= 1.01870e+03; step_size= 0.00500
# 	point   =(R_E= 3.679665e-05; p_A=-1.798864e+05; )
# 	output  =1016.3371359848294; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0298; p_A= 0.9996; )
# 	change  =(R_E=-1.785812e-08; p_A=-9.995570e+02; )
# 40. step; last_best= 1.01633e+03; absolute_best= 1.01633e+03; step_size= 0.00500
# 	point   =(R_E= 3.677879e-05; p_A=-1.808859e+05; )
# 	output  =1013.7992380888596; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9999; p_A= 0.0126; )
# 	change  =(R_E= 5.999525e-07; p_A=-1.258606e+01; )
# 41. step; last_best= 1.01380e+03; absolute_best= 1.01380e+03; step_size= 0.00500
# 	point   =(R_E= 3.737874e-05; p_A=-1.808985e+05; )
# 	output  =1011.1214658897064; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0346; p_A= 0.9994; )
# 	change  =(R_E= 2.078026e-08; p_A=-9.994001e+02; )
# 42. step; last_best= 1.01107e+03; absolute_best= 1.01107e+03; step_size= 0.00500
# 	point   =(R_E= 3.739953e-05; p_A=-1.818979e+05; )
# 	output  =1008.6045908751463; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9998; p_A= 0.0177; )
# 	change  =(R_E= 5.999058e-07; p_A=-1.772293e+01; )
# 43. step; last_best= 1.00860e+03; absolute_best= 1.00860e+03; step_size= 0.00500
# 	point   =(R_E= 3.799943e-05; p_A=-1.819156e+05; )
# 	output  =1005.5828714944178; success=True; modifier=1.0;
# 	gradient=(R_E=-0.0402; p_A= 0.9992; )
# 	change  =(R_E= 2.410517e-08; p_A=-9.991926e+02; )
# 44. step; last_best= 1.00557e+03; absolute_best= 1.00557e+03; step_size= 0.00500
# 	point   =(R_E= 3.802354e-05; p_A=-1.829148e+05; )
# 	output  =1001.8557088749533; success=True; modifier=2.0;
# 	gradient=(R_E=-0.9838; p_A= 0.1793; )
# 	change  =(R_E= 1.180551e-06; p_A=-3.586178e+02; )
# 45. step; last_best= 1.00186e+03; absolute_best= 1.00186e+03; step_size= 0.01000
# 	point   =(R_E= 3.920409e-05; p_A=-1.832734e+05; )
# 	output  =996.8105608333453; success=True; modifier=0.5;
# 	gradient=(R_E= 0.3383; p_A= 0.9410; )
# 	change  =(R_E=-2.029666e-07; p_A=-9.410464e+02; )
# 46. step; last_best= 9.96804e+02; absolute_best= 9.96804e+02; step_size= 0.00500
# 	point   =(R_E= 3.900112e-05; p_A=-1.842145e+05; )
# 	output  =979.9897292749464; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7720; p_A= 0.6356; )
# 	change  =(R_E= 1.852747e-06; p_A=-2.542598e+03; )
# 47. step; last_best= 9.79989e+02; absolute_best= 9.79989e+02; step_size= 0.02000
# 	point   =(R_E= 4.085387e-05; p_A=-1.867571e+05; )
# 	output  =975.3771725799281; success=True; modifier=0.5;
# 	gradient=(R_E=-0.0699; p_A= 0.9976; )
# 	change  =(R_E= 8.384055e-08; p_A=-1.995113e+03; )
# 48. step; last_best= 9.75362e+02; absolute_best= 9.75362e+02; step_size= 0.01000
# 	point   =(R_E= 4.093771e-05; p_A=-1.887522e+05; )
# 	output  =971.3251259874363; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9836; p_A=-0.1805; )
# 	change  =(R_E= 1.180282e-06; p_A= 3.610723e+02; )
# 49. step; last_best= 9.71325e+02; absolute_best= 9.71325e+02; step_size= 0.01000
# 	point   =(R_E= 4.211799e-05; p_A=-1.883911e+05; )
# 	output  =966.3225127378308; success=True; modifier=0.5;
# 	gradient=(R_E= 0.3052; p_A= 0.9523; )
# 	change  =(R_E=-1.831135e-07; p_A=-9.522917e+02; )
# 50. step; last_best= 9.66317e+02; absolute_best= 9.66317e+02; step_size= 0.00500
# 	point   =(R_E= 4.193488e-05; p_A=-1.893434e+05; )
# 	output  =951.9377909565814; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6691; p_A= 0.7432; )
# 	change  =(R_E= 1.605747e-06; p_A=-2.972830e+03; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 51. step; last_best= 9.51930e+02; absolute_best= 9.51930e+02; step_size= 0.02000
# 	point   =(R_E= 4.354062e-05; p_A=-1.923162e+05; )
# 	output  =919.0565275883788; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6286; p_A= 0.7778; )
# 	change  =(R_E= 6.034221e-06; p_A=-1.244412e+04; )
# 52. step; last_best= 9.19053e+02; absolute_best= 9.19053e+02; step_size= 0.08000
# 	point   =(R_E= 4.957484e-05; p_A=-2.047604e+05; )
# 	output  =946.236354248223; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9980; p_A=-0.0635; )
# 	change  =(R_E= 2.395163e-06; p_A= 2.538277e+02; )
# 53. step; last_best= 9.46236e+02; absolute_best= 9.19053e+02; step_size= 0.02000
# 	point   =(R_E= 5.197001e-05; p_A=-2.045065e+05; )
# 	output  =919.2480481194706; success=True; modifier=1.0;
# 	gradient=(R_E= 0.7488; p_A= 0.6628; )
# 	change  =(R_E=-1.797108e-06; p_A=-2.651208e+03; )
# 54. step; last_best= 9.19238e+02; absolute_best= 9.19053e+02; step_size= 0.02000
# 	point   =(R_E= 5.017290e-05; p_A=-2.071577e+05; )
# 	output  =916.4439621720122; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8773; p_A=-0.4800; )
# 	change  =(R_E= 5.263523e-07; p_A= 4.800267e+02; )
# 55. step; last_best= 9.16443e+02; absolute_best= 9.16443e+02; step_size= 0.00500
# 	point   =(R_E= 5.069925e-05; p_A=-2.066777e+05; )
# 	output  =915.4553678641953; success=True; modifier=2.0;
# 	gradient=(R_E=-0.4502; p_A= 0.8929; )
# 	change  =(R_E= 5.401943e-07; p_A=-1.785894e+03; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 56. step; last_best= 9.15447e+02; absolute_best= 9.15447e+02; step_size= 0.01000
# 	point   =(R_E= 5.123945e-05; p_A=-2.084636e+05; )
# 	output  =915.0246571170123; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9284; p_A=-0.3715; )
# 	change  =(R_E= 2.785242e-07; p_A= 1.857736e+02; )
# 57. step; last_best= 9.15025e+02; absolute_best= 9.15025e+02; step_size= 0.00250
# 	point   =(R_E= 5.151797e-05; p_A=-2.082778e+05; )
# 	output  =914.897479356968; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1605; p_A= 0.9870; )
# 	change  =(R_E=-2.407921e-08; p_A=-2.467578e+02; )
# 58. step; last_best= 9.14896e+02; absolute_best= 9.14896e+02; step_size= 0.00125
# 	point   =(R_E= 5.149389e-05; p_A=-2.085246e+05; )
# 	output  =914.7810887043904; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9550; p_A= 0.2965; )
# 	change  =(R_E= 1.432535e-07; p_A=-7.413280e+01; )
# 59. step; last_best= 9.14781e+02; absolute_best= 9.14781e+02; step_size= 0.00125
# 	point   =(R_E= 5.163714e-05; p_A=-2.085987e+05; )
# 	output  =914.6341347593759; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1000; p_A= 0.9950; )
# 	change  =(R_E= 2.999571e-08; p_A=-4.974944e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 60. step; last_best= 9.14629e+02; absolute_best= 9.14629e+02; step_size= 0.00250
# 	point   =(R_E= 5.166714e-05; p_A=-2.090962e+05; )
# 	output  =914.4882935430064; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9519; p_A=-0.3066; )
# 	change  =(R_E= 1.427776e-07; p_A= 7.664069e+01; )
# 61. step; last_best= 9.14488e+02; absolute_best= 9.14488e+02; step_size= 0.00125
# 	point   =(R_E= 5.180992e-05; p_A=-2.090196e+05; )
# 	output  =914.3788479893093; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1384; p_A= 0.9904; )
# 	change  =(R_E= 4.152186e-08; p_A=-4.951878e+02; )
# C:\Users\aron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\integrate\_ode.py:1348: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 62. step; last_best= 9.14374e+02; absolute_best= 9.14374e+02; step_size= 0.00250
# 	point   =(R_E= 5.185144e-05; p_A=-2.095148e+05; )
# 	output  =914.2092985729975; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9715; p_A=-0.2371; )
# 	change  =(R_E= 1.457243e-07; p_A= 5.926488e+01; )
# 63. step; last_best= 9.14209e+02; absolute_best= 9.14209e+02; step_size= 0.00125
# 	point   =(R_E= 5.199716e-05; p_A=-2.094555e+05; )
# 	output  =914.0503981512635; success=True; modifier=2.0;
# 	gradient=(R_E=-0.2977; p_A= 0.9547; )
# 	change  =(R_E= 8.929612e-08; p_A=-4.773369e+02; )
# 64. step; last_best= 9.14048e+02; absolute_best= 9.14048e+02; step_size= 0.00250
# 	point   =(R_E= 5.208646e-05; p_A=-2.099328e+05; )
# 	output  =913.9469934918126; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9842; p_A=-0.1773; )
# 	change  =(R_E= 1.476234e-07; p_A= 4.432602e+01; )
# 65. step; last_best= 9.13947e+02; absolute_best= 9.13947e+02; step_size= 0.00125
# 	point   =(R_E= 5.223408e-05; p_A=-2.098885e+05; )
# 	output  =913.8697189343031; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0314; p_A= 0.9995; )
# 	change  =(R_E=-4.710313e-09; p_A=-2.498767e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 66. step; last_best= 9.13868e+02; absolute_best= 9.13868e+02; step_size= 0.00125
# 	point   =(R_E= 5.222937e-05; p_A=-2.101384e+05; )
# 	output  =913.8068936176196; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9987; p_A= 0.0509; )
# 	change  =(R_E= 1.498058e-07; p_A=-1.271712e+01; )
# 67. step; last_best= 9.13807e+02; absolute_best= 9.13807e+02; step_size= 0.00125
# 	point   =(R_E= 5.237918e-05; p_A=-2.101511e+05; )
# 	output  =913.7470548066573; success=True; modifier=1.0;
# 	gradient=(R_E= 0.2933; p_A= 0.9560; )
# 	change  =(R_E=-4.399716e-08; p_A=-2.390040e+02; )
# 68. step; last_best= 9.13746e+02; absolute_best= 9.13746e+02; step_size= 0.00125
# 	point   =(R_E= 5.233518e-05; p_A=-2.103901e+05; )
# 	output  =913.6851250053829; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9996; p_A=-0.0268; )
# 	change  =(R_E= 1.499462e-07; p_A= 6.694461e+00; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 69. step; last_best= 9.13685e+02; absolute_best= 9.13685e+02; step_size= 0.00125
# 	point   =(R_E= 5.248513e-05; p_A=-2.103834e+05; )
# 	output  =913.629160197518; success=True; modifier=0.5;
# 	gradient=(R_E= 0.3151; p_A= 0.9491; )
# 	change  =(R_E=-2.362893e-08; p_A=-1.186343e+02; )
# 70. step; last_best= 9.13629e+02; absolute_best= 9.13629e+02; step_size= 0.00063
# 	point   =(R_E= 5.246150e-05; p_A=-2.105021e+05; )
# 	output  =913.4390043998119; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6231; p_A= 0.7822; )
# 	change  =(R_E= 1.869173e-07; p_A=-3.910880e+02; )
# 71. step; last_best= 9.13439e+02; absolute_best= 9.13439e+02; step_size= 0.00250
# 	point   =(R_E= 5.264842e-05; p_A=-2.108931e+05; )
# 	output  =912.9991983071033; success=True; modifier=4.0;
# 	gradient=(R_E=-0.5092; p_A= 0.8607; )
# 	change  =(R_E= 6.110018e-07; p_A=-1.721334e+03; )
# 72. step; last_best= 9.12997e+02; absolute_best= 9.12997e+02; step_size= 0.01000
# 	point   =(R_E= 5.325942e-05; p_A=-2.126145e+05; )
# 	output  =913.0143870977673; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8952; p_A=-0.4457; )
# 	change  =(R_E= 2.685614e-07; p_A= 2.228276e+02; )
# 73. step; last_best= 9.13014e+02; absolute_best= 9.12997e+02; step_size= 0.00250
# 	point   =(R_E= 5.352798e-05; p_A=-2.123917e+05; )
# 	output  =912.8203667286605; success=True; modifier=0.5;
# 	gradient=(R_E= 0.6946; p_A= 0.7194; )
# 	change  =(R_E=-1.041918e-07; p_A=-1.798461e+02; )
# 74. step; last_best= 9.12820e+02; absolute_best= 9.12820e+02; step_size= 0.00125
# 	point   =(R_E= 5.342379e-05; p_A=-2.125715e+05; )
# 	output  =912.689738744545; success=True; modifier=4.0;
# 	gradient=(R_E=-0.4678; p_A= 0.8839; )
# 	change  =(R_E= 2.806595e-07; p_A=-8.838524e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 75. step; last_best= 9.12687e+02; absolute_best= 9.12687e+02; step_size= 0.00500
# 	point   =(R_E= 5.370445e-05; p_A=-2.134553e+05; )
# 	output  =912.644820333967; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8971; p_A=-0.4418; )
# 	change  =(R_E= 1.345689e-07; p_A= 1.104438e+02; )
# 76. step; last_best= 9.12645e+02; absolute_best= 9.12645e+02; step_size= 0.00125
# 	point   =(R_E= 5.383902e-05; p_A=-2.133449e+05; )
# 	output  =912.6147960257342; success=True; modifier=0.5;
# 	gradient=(R_E= 0.5495; p_A= 0.8355; )
# 	change  =(R_E=-4.121452e-08; p_A=-1.044345e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 77. step; last_best= 9.12614e+02; absolute_best= 9.12614e+02; step_size= 0.00063
# 	point   =(R_E= 5.379780e-05; p_A=-2.134493e+05; )
# 	output  =912.6133374055468; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8213; p_A=-0.5704; )
# 	change  =(R_E= 1.539999e-08; p_A= 1.782654e+01; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 78. step; last_best= 9.12613e+02; absolute_best= 9.12613e+02; step_size= 0.00016
# 	point   =(R_E= 5.381320e-05; p_A=-2.134315e+05; )
# 	output  =912.5962264663553; success=True; modifier=4.0;
# 	gradient=(R_E=-0.3577; p_A= 0.9339; )
# 	change  =(R_E= 2.682423e-08; p_A=-1.167317e+02; )
# 79. step; last_best= 9.12596e+02; absolute_best= 9.12596e+02; step_size= 0.00063
# 	point   =(R_E= 5.384003e-05; p_A=-2.135482e+05; )
# 	output  =912.5890340699468; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9961; p_A= 0.0878; )
# 	change  =(R_E= 3.735526e-08; p_A=-5.486068e+00; )
# 80. step; last_best= 9.12589e+02; absolute_best= 9.12589e+02; step_size= 0.00031
# 	point   =(R_E= 5.387738e-05; p_A=-2.135537e+05; )
# 	output  =912.5811566946678; success=True; modifier=2.0;
# 	gradient=(R_E=-0.0098; p_A= 1.0000; )
# 	change  =(R_E= 7.330372e-10; p_A=-1.249940e+02; )
# 81. step; last_best= 9.12581e+02; absolute_best= 9.12581e+02; step_size= 0.00063
# 	point   =(R_E= 5.387811e-05; p_A=-2.136787e+05; )
# 	output  =912.5683468963155; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9958; p_A=-0.0912; )
# 	change  =(R_E= 3.734369e-08; p_A= 5.700584e+00; )
# 82. step; last_best= 9.12568e+02; absolute_best= 9.12568e+02; step_size= 0.00031
# 	point   =(R_E= 5.391546e-05; p_A=-2.136730e+05; )
# 	output  =912.5401784445642; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7382; p_A= 0.6746; )
# 	change  =(R_E= 1.107252e-07; p_A=-1.686543e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 	Warning, forward point failed, trial_num=2; current_delta=2e-05
# 83. step; last_best= 9.12540e+02; absolute_best= 9.12540e+02; step_size= 0.00125
# 	point   =(R_E= 5.402618e-05; p_A=-2.138417e+05; )
# 	output  =912.5317067541118; success=True; modifier=0.25;
# 	gradient=(R_E= 0.4485; p_A= 0.8938; )
# 	change  =(R_E=-1.682018e-08; p_A=-5.586023e+01; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 84. step; last_best= 9.12531e+02; absolute_best= 9.12531e+02; step_size= 0.00031
# 	point   =(R_E= 5.400936e-05; p_A=-2.138975e+05; )
# 	output  =912.5203754965258; success=True; modifier=2.0;
# 	gradient=(R_E=-0.8594; p_A= 0.5113; )
# 	change  =(R_E= 6.445345e-08; p_A=-6.391732e+01; )
# 85. step; last_best= 9.12520e+02; absolute_best= 9.12520e+02; step_size= 0.00063
# 	point   =(R_E= 5.407382e-05; p_A=-2.139615e+05; )
# 	output  =912.5151939889914; success=True; modifier=0.25;
# 	gradient=(R_E= 0.3537; p_A= 0.9354; )
# 	change  =(R_E=-6.632100e-09; p_A=-2.922982e+01; )
# 86. step; last_best= 9.12515e+02; absolute_best= 9.12515e+02; step_size= 0.00016
# 	point   =(R_E= 5.406718e-05; p_A=-2.139907e+05; )
# 	output  =912.5019004997857; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6879; p_A= 0.7258; )
# 	change  =(R_E= 5.159320e-08; p_A=-9.072458e+01; )
# 87. step; last_best= 9.12502e+02; absolute_best= 9.12502e+02; step_size= 0.00063
# 	point   =(R_E= 5.411878e-05; p_A=-2.140814e+05; )
# 	output  =912.4971689189493; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1768; p_A= 0.9842; )
# 	change  =(R_E=-6.631078e-09; p_A=-6.151510e+01; )
# 88. step; last_best= 9.12497e+02; absolute_best= 9.12497e+02; step_size= 0.00031
# 	point   =(R_E= 5.411215e-05; p_A=-2.141429e+05; )
# 	output  =912.4918049419008; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9856; p_A= 0.1691; )
# 	change  =(R_E= 3.696002e-08; p_A=-1.056815e+01; )
# 89. step; last_best= 9.12492e+02; absolute_best= 9.12492e+02; step_size= 0.00031
# 	point   =(R_E= 5.414911e-05; p_A=-2.141535e+05; )
# 	output  =912.4885304632629; success=True; modifier=1.0;
# 	gradient=(R_E= 0.2207; p_A= 0.9753; )
# 	change  =(R_E=-8.277689e-09; p_A=-6.095832e+01; )
# 90. step; last_best= 9.12488e+02; absolute_best= 9.12488e+02; step_size= 0.00031
# 	point   =(R_E= 5.414083e-05; p_A=-2.142145e+05; )
# 	output  =912.4844954198114; success=True; modifier=0.5;
# 	gradient=(R_E=-1.0000; p_A=-0.0093; )
# 	change  =(R_E= 1.874918e-08; p_A= 2.914658e-01; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 91. step; last_best= 9.12484e+02; absolute_best= 9.12484e+02; step_size= 0.00016
# 	point   =(R_E= 5.415958e-05; p_A=-2.142142e+05; )
# 	output  =912.4686838781982; success=True; modifier=0.5;
# 	gradient=(R_E=-0.5629; p_A= 0.8265; )
# 	change  =(R_E= 5.277522e-09; p_A=-1.291407e+01; )

# %%
all_central_points = []
central_outputs = []
for points in datas:
    outputs = [data[to_optimize] for data in points]
    central_outputs.append(outputs[0])
    #central_outputs.append(min(outputs))
    all_central_points.append(points[0])
value1 = [data[key1] for data in all_central_points]
value2 = [data[key2] for data in all_central_points]
start = len(all_central_points) // 2
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].plot(value1[:start+1], value2[:start+1], '.-', color='blue', linewidth=1, zorder=1)
ax[0].plot(value1[start:], value2[start:], '.-', color='lightblue', linewidth=0.5, zorder=1)
ax[1].plot(value1[start:], value2[start:], '.-', color='lightblue', linewidth=1, zorder=1)
ax[0].scatter([value1[0]], [value2[0]], color='green', zorder=2, s=25)   # start point
ax[0].scatter([value1[-1]], [value2[-1]], color='red', zorder=2, s=25)   # optimal point
ax[1].scatter([value1[-1]], [value2[-1]], color='red', zorder=2, s=25)   # optimal point
ax[0].text(value1[0], value2[0], f'  start: ({value1[0]:.2e}, {value2[0]:.2e})', fontsize=12)
ax[1].text(value1[-1], value2[-1], f'  end: ({value1[-1]:.2e}, {value2[-1]:.2e})', fontsize=12)
ax[0].set_title('All points')
ax[1].set_title('Near optimal point')
ax[0].set_xlabel(key1)
ax[0].set_ylabel(key2)
ax[1].set_xlabel(key1)
ax[1].set_ylabel(key2)
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(12, 5))
ax.plot(range(len(central_outputs[:])), central_outputs[:], '.-')
ax.set_ylim([0.999*min(central_outputs), 1.05*min(central_outputs)])
ax.set_xticks(range(0, len(central_outputs[:]), 10), minor=False)
ax.set_xticks(range(len(central_outputs[:])), minor=True)
ax.tick_params(which='major', axis='x', width=2, grid_color='darkgrey', grid_linewidth=1.5)
ax.set_xlabel('step number [-]')
ax.set_ylabel(to_optimize)
ax.grid(which='both')
#plt.yscale('log')
plt.show()
print(f'last output: {central_outputs[-1]: .2f}')
# Out:
# last output:  912.48

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 10))
levels = np.linspace(vmin, vmax, 250)
maxi = np.log10(max(central_outputs))
cp = ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=min(vmax, maxi), extend='max')
ax.contour(X, Y, Z, levels=np.linspace(vmin, vmax, contour_levels), colors='black', linewidths=0.5)
colorbar_title = '$Energy\ demand\ [MJ/kg_{' + gd.de.target_specie + '}]$'
cbar = fig.colorbar(cp, label=colorbar_title) # Add a colorbar to a plot

ax.plot(value1[:], value2[:], '.-', color='blue', linewidth=1, zorder=1)
ax.scatter([value1[0]], [value2[0]], color='green', zorder=2, s=25)   # start point
ax.scatter([value1[-1]], [value2[-1]], color='green', zorder=2, s=25)   # optimal point
ax.text(value1[0], value2[0], f'  start: ({value1[0]:.2e}, {value2[0]:.2e})', fontsize=12)
ax.set_title('All points')
ax.set_xlabel(key1)
ax.set_ylabel(key2)

range1 = max(value1) - min(value1)
range2 = max(value2) - min(value2)
range1 = [min(value1) - 0.05*range1, max(value1) + 0.05*range1]
range2 = [min(value2) - 0.05*range2, max(value2) + 0.05*range2]
ax.set_xlim(range1)
ax.set_ylim(range2)

ticks = cbar.get_ticks()
cbar.set_ticks(ticks)
if use_log10:
    cbar.set_ticklabels([f'{10**tick:.0f}' for tick in ticks])  # Format as powers of 10
else:
    cbar.set_ticklabels([f'{tick:.1f}' for tick in ticks])
cbar.ax.tick_params(labelsize=12)  # Adjust font size
plt.show()
