# %% [markdown]
# ## Importing libraries, parameters.py

# %%
"""Create parameters.py and load it"""

# Directory for .inp file:
path = 'INP file examples\\chem_Otomo2018_without_O_FIXED_by_Cantera.inp'

# import libraries:
import importlib   # For reloading your own files
from termcolor import colored   # for colored error messages

# import inp_data_extractor.py as inp:
try:
    import inp_data_extractor as inp
except ImportError:
    try:
        from Bubble_dynamics_simulation import inp_data_extractor as inp
    except ImportError as error:
        print(colored(f'Error, \'inp_data_extractor.py\' not found', 'red'))
        raise error
    except Exception as error:
        print(colored(f'Error, \'inp_data_extractor.py\' failed to load', 'red'))
        raise error
except Exception as error:
    print(colored(f'Error, \'inp_data_extractor.py\' failed to load', 'red'))
    raise error
importlib.reload(inp)   # reload changes you made

# create parameters.py
inp.extract(path)

import parameters as par   # numeric constants and coefficents
importlib.reload(par)   # reload changes you made
print(par.model)
# Out:
# path=INP file examples\chem_Otomo2018_without_O_FIXED_by_Cantera.inp
# Note, lambda value for specie 'H' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NH2' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NH' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N' is not in data.py: 0.0 is used
# Note, lambda value for specie 'NNH' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H4' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H3' is not in data.py: 0.0 is used
# Note, lambda value for specie 'N2H2' is not in data.py: 0.0 is used
# Note, lambda value for specie 'H2NN' is not in data.py: 0.0 is used
# Warning, third body 'H2O' is not in species in line 63 (' H2/2.5/ H2O/12/ AR/0.0/ ') in reaction 'H2+M=H+H+M'
# Warning, third body 'AR' is not in species in line 63 (' H2/2.5/ H2O/12/ AR/0.0/ ') in reaction 'H2+M=H+H+M'
# model: chem_Otomo2018_without_O_FIXED_by_Cantera
# File 'parameters.py' succesfully created
# chem_Otomo2018_without_O_FIXED_by_Cantera

# %%
"""Libraries"""

# for plotting:
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

import numpy as np   # matrices, math
import time   # runtime measurement
import os    # file management
import pandas as pd   # data frames
from multiprocessing import Pool, cpu_count   # multithreading
import importlib   # reload changes you made

# import gradient_descent.py as gd:
_already_imported = 'gd' in globals()
try:
    import gradient_descent as gd
except ImportError:
    try:
        from  Bubble_dynamics_simulation import gradient_descent as gd
    except ImportError as _error:
        print(colored(f'Error, \'gradient_descent.py\' not found', 'red'))
        raise _error
    except Exception as _error:
        print(colored(f'Error, \'gradient_descent.py\' failed to load', 'red'))
        raise _error
except Exception as _error:
    print(colored(f'Error, \'gradient_descent.py\' failed to load', 'red'))
    raise _error
if _already_imported: importlib.reload(gd)   # reload changes you made
# Out:
# model: chem_Otomo2018_without_O_FIXED_by_Cantera
# target specie: NH3
# excitation: sin_impulse (control parameters: ['p_A', 'freq', 'n'])
# enable heat transfer: True	enable evaporation: False	enable reactions: True	enable dissipated energy: True	enable reaction rate threshold: True

# %% [markdown]
# ## Ranges, settings

# %%
# Control parameter ranges
# make sure, it's only 2D

ranges = dict(
  # Initial conditions:
    # bubble equilibrium radius [m]
    R_E = [1e-6*x for x in [5.0, 125.0]], # [um --> m]
    # initial radius / equilibrium radius R_0/R_E [-]
    ratio = [1.0],
    # indexes of species in initial bubble
    gases=[[par.index['N2'], par.index['H2']]],
    # Molar fractions of species in the initial bubble (H2 and N2) [-]
    fractions=[[0.25, 0.75]],
  # Ambient parameters:
    # ambient pressure [Pa]
    P_amb = [x * par.atm2Pa for x in [1.0]], # [atm --> Pa]
    # ambient temperature [K]       
    T_inf = [par.absolute_zero + x for x in [20.0]], # [°C --> K]
  # Liquid parameters:
    # water accommodation coefficient [-]
    alfa_M = [0.35],
    # vapour pressure [Pa]
    #P_v = par.P_v, # calculated from T_inf
    # dynamic viscosity [Pa*s]
    #mu_L = par.mu_L, # calculated from T_inf
    # density [kg/m^3]
    rho_L =  [998.20],
    # sound speed [m/s]
    c_L = [par.c_L],
    # surfactant (surface tension modfier) [-]
    surfactant = [1.0],
  # Excitation parameters: (excitation_type = sin_impulse)
    # excitation amplitude [Pa]
    p_A = [-x * par.bar2Pa for x in [1.0, 3.0]], # [bar --> Pa]
    # excitation frequency [Hz]
    freq =  [20000.00],
    # excitation duration in period times [-]
    n =  [1.00],
)

for key in gd.de.excitation_args:
    if key not in ranges:
        print(colored(f'Error, {key} not in ranges', 'red'))

examined_keys = []
for key in ranges:
    if len(ranges[key]) > 1:
        examined_keys.append(key)

print(f'The following control parameters will be examined: {examined_keys}')
if len(examined_keys) != 2:
    print(colored(f'Error, exactly 2 control parameters have to be examined', 'red'))
key1 = examined_keys[0]
key2 = examined_keys[1]
# Out:
# The following control parameters will be examined: ['R_E', 'p_A']

# %%
# Settings:
to_optimize = 'energy_demand'   # key in data from de.get_data()
directory = 'test_1atm_20000Hz_2D'   # appropiate 2D bruteforce parameter study
file_base_name = 'output_'

# %% [markdown]
# ## Reading files, 2D contour plot
# This is optional, you don't have to place a contour plot underneath the gadient descent visualization.
# The bruteforce param study should be 2D with the same range as above, and uniform spacement.

# %%
# create a dataframe
all_data = pd.DataFrame()
num = 0

# iterate trough all files in directory (including subdirectories)
for (root, dirs, files) in os.walk(directory):
    for file in files:
        # ignore python rubish
        if 'ipynb_checkpoints' in root:
            continue
        # check if it's a CSV starting with file_base_name
        if file[-4:] != '.csv':
            continue
        if file[:len(file_base_name)] != file_base_name:
            continue

        # read file
        num += 1
        current_data = pd.read_csv(os.path.join(root, file))

        # Cast object-dtype columns with all-bool values to bool dtype
        for col in current_data.columns:
            if current_data[col].dtype == 'object' and all(current_data[col].dropna().map(lambda x: isinstance(x, bool))):
                current_data[col] = current_data[col].astype(bool)

                
        print(f'\t{file: <24} ({current_data.shape[0]: >4} rows)')
        all_data = pd.concat([all_data, current_data])

# locate successful simulations (or use all_data['success'] == True)
good_data = all_data.loc[
    (all_data['error_code'] % 100 <= 3) & ((all_data['error_code'] // 100) % 10 != 1) &
    (all_data['energy_demand'] > 0.0) & (all_data['energy_demand'] == all_data['energy_demand']) # positive not NaN
]

good_data = good_data.sort_values(['ID'], ascending=True)
print(f'Good data: {good_data.shape[0]} rows ({100*good_data.shape[0]/all_data.shape[0]: .2f} %)')
# Out:
# 	output_1.csv             (2500 rows)
# Good data: 2437 rows ( 97.48 %)

# %%
# Check ranges vs good_data:
for key in ranges:
    llist = good_data[key].unique()
    llist.sort()
    if len(llist) > 1 and len(ranges[key]) < 2:
        print(colored(f'Error, {key} has {len(llist)} distinct values, but it should be constant {ranges[key][0]}', 'red'))
    if len(ranges[key]) > 1:
        if len(llist) < 2:
            print(colored(f'Error, {key} should have  values between {ranges[key][0]} and {ranges[key][1]}', 'red'))
        if abs(llist[0] - min(ranges[key])) / abs(min(ranges[key]) + 1e-10) > 1e-5:
            print(colored(f'Error, {key} has values between {llist[0]} and {llist[-1]}, but it should be between {ranges[key][0]} and {ranges[key][1]}', 'red'))
        if abs(llist[-1] - max(ranges[key])) / abs(max(ranges[key]) + 1e-10) > 1e-5:
            print(colored(f'Error, {key} has values between {llist[0]} and {llist[-1]}, but it should be between {ranges[key][0]} and {ranges[key][1]}', 'red'))

# %%
# list unique values:

output_list = list(good_data[to_optimize])
list1 = list(good_data[key1])
list2 = list(good_data[key2])
value_list1 = good_data[key1].unique()
value_list2 = good_data[key2].unique()
value_list1.sort()
value_list2.sort()
print(f'{key1}: from {value_list1[0]} to {value_list1[-1]} ({len(value_list1)} values)')
print(f'{key2}: from {value_list2[0]} to {value_list2[-1]} ({len(value_list2)} values)')
# Out:
# R_E: from 5e-06 to 0.000125 (50 values)
# p_A: from -300000.0 to -100000.0 (50 values)

# %%
# Interpolate missing values
# Settings:
catch_outliers = True
use_log10 = True
fix_missing_values = True

# Assemble meshgrid, and existing data points:
combined = []   # (key1, key2) pairs in order
output_list = []    # values of to_optimize in the sameorder
for x in value_list1:
    for y in value_list2:
        energy = good_data.loc[(good_data[key1] == x) & (good_data[key2] == y), to_optimize]
        if len(energy) == 1:
            energy = energy.values[0]
            combined.append((x, y))
            output_list.append(energy)
            
if use_log10:
    output_list = list(np.log10(output_list))
vmin = min(output_list) # min
vmax = 2.0*vmin if use_log10 else 100.0*vmin    # max
X, Y = np.meshgrid(value_list1, value_list2)
Z = np.zeros(X.shape)
fixed = 0

# Iterate trough all possible combinations:
for i, x in enumerate(value_list1):
    for j, y in enumerate(value_list2):
        if (x, y) not in combined:  # missing values
            index = i * len(value_list2) + j
            y1 = combined[index-1][1]; y2 = combined[index][1]
            o1 = output_list[index-1]; o2 = output_list[index]
            if abs(y2 - y1) > 0.3*abs(value_list2[-1] - value_list2[0]):
                # if the gap of missing values is too large
                extrapolation = 30.0 if use_log10 else 1e30
            else:
                # linear interpolation
                extrapolation = o1 + (o2 - o1) * (y - y1) / (y2 - y1)

            combined = combined[:index] + [(x, y)] + combined[index:]
            if fix_missing_values:
                output_list = output_list[:index] + [extrapolation] + output_list[index:]
            else:
                output_list = output_list[:index] + [vmax] + output_list[index:]
            Z[j, i] = output_list[index]
            fixed += 1

        else: # outliers
            index = combined.index((x, y))
            big = 2.0 if use_log10 else 100000.0 # ratio of outlier and neigbouring value

            if (i != 0 and i != len(value_list1)-1 and # not on the edge
                j != 0 and j != len(value_list2)-1 and  # not on the edge
                output_list[index-1] < vmax and output_list[index+1] < vmax and    # neighbouring values are not too big
                output_list[index] > big*output_list[index+1] and    # much bigger than the next
                output_list[index] > big*output_list[index-1] and catch_outliers):   # much bigger than the previous

                output_list[index] = (output_list[index-1] + output_list[index+1]) / 2
                print(f'{index}: {key1}={x : .4e}, {key2}={y: .4e}, output={output_list[index]: .3f}')
            Z[j, i] = output_list[index]
            

print(f'{fixed} missing values fixed')
# Out:
# 63 missing values fixed

# %%
# Plot:
contour_levels = 20
title = ''
xlabel = key1
ylabel = key2

fig,ax=plt.subplots(1, 1, figsize=(12, 10))
levels = np.linspace(vmin, vmax, 250)
cp = ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=vmax, extend='max')
ax.contour(X, Y, Z, levels=np.linspace(vmin, vmax, contour_levels), colors='black', linewidths=0.5)
colorbar_title = '$Energy\ demand\ [MJ/kg_{' + gd.de.target_specie + '}]$'
cbar = fig.colorbar(cp, label=colorbar_title) # Add a colorbar to a plot
ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ticks = cbar.get_ticks()
cbar.set_ticks(ticks)
if use_log10:
    cbar.set_ticklabels([f'{10**tick:.0f}' for tick in ticks])  # Format as powers of 10
else:
    cbar.set_ticklabels([f'{tick:.1f}' for tick in ticks])
cbar.ax.tick_params(labelsize=12)  # Adjust font size
plt.show()

# %% [markdown]
# ## Plot gradient descent search

# %%
# Generate random starting_point:

start_point = gd.rand_point(ranges, padding=0.01)   # random point in ranges

print(f'Starting point: ({key1}={start_point[key1]}, {key2}={start_point[key2]})')
data, success = gd.evaluate(start_point, to_optimize, t_int=[0.0, 1.0], LSODA_timeout=10, Radau_timeout=0)
if not success:
    print(colored(f'Error, simulation failed', 'red'))
else:
    print(f'Output in starting point: {data[to_optimize]: .4f}')

# Plot:

fig,ax=plt.subplots(1, 1, figsize=(4, 4))
levels = np.linspace(vmin, vmax, 100)
ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=vmax, extend='max')
ax.scatter(start_point[key1], start_point[key2], color='black', s=100, label='Starting point')
ax.axis('off')
plt.show()
# Out:
# Starting point: (R_E=3.107109769359973e-05, p_A=-121195.8789363806)
# Output in starting point:  11882689.6165

# %%
start_point_copy = gd.de.copy(start_point)

datas, last_bests, elapsed_time = gd.gradient_descent(
    ranges=ranges, path='', to_optimize=to_optimize, start_point=start_point_copy,
    step_limit=100, first_step=0.01, min_step=1e-4, delta=1e-5,
    verbose=True, t_int=np.array([0.0, 1.0]), LSODA_timeout=10.0, Radau_timeout=0.0
)
# Out:
# 0. step; last_best= 1.18827e+07; absolute_best= 1.18827e+07; step_size= 0.01000
# 	point   =(R_E= 3.107110e-05; p_A=-1.211959e+05; )
# 	output  =359354.41708680586; success=True; modifier=4.0;
# 	gradient=(R_E= 0.2412; p_A= 0.9705; )
# 	change  =(R_E=-1.157939e-06; p_A=-7.763729e+03; )
# 1. step; last_best= 3.59354e+05; absolute_best= 3.59354e+05; step_size= 0.04000
# 	point   =(R_E= 2.991316e-05; p_A=-1.289596e+05; )
# 	output  =1195.7552186822757; success=True; modifier=4.0;
# 	gradient=(R_E= 0.3356; p_A= 0.9420; )
# 	change  =(R_E=-6.444028e-06; p_A=-3.014384e+04; )
# 2. step; last_best= 1.19575e+03; absolute_best= 1.19575e+03; step_size= 0.16000
# 	point   =(R_E= 2.346913e-05; p_A=-1.591035e+05; )
# C:\Users\aron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Repeated convergence failures (perhaps bad Jacobian or tolerances).
#   solver._y, solver.t = integrator.run(
# 	output  =1235.418442243749; success=True; modifier=0.25;
# 	gradient=(R_E=-0.3312; p_A= 0.9436; )
# 	change  =(R_E= 1.589674e-06; p_A=-7.548535e+03; )
# 3. step; last_best= 1.23533e+03; absolute_best= 1.19575e+03; step_size= 0.04000
# 	point   =(R_E= 2.505880e-05; p_A=-1.666520e+05; )
# 	output  =1130.7617750950442; success=True; modifier=0.5;
# 	gradient=(R_E=-0.7925; p_A=-0.6098; )
# 	change  =(R_E= 1.902109e-06; p_A= 2.439252e+03; )
# 4. step; last_best= 1.13075e+03; absolute_best= 1.13075e+03; step_size= 0.02000
# 	point   =(R_E= 2.696091e-05; p_A=-1.642127e+05; )
# 	output  =1112.9818564430022; success=True; modifier=1.0;
# 	gradient=(R_E=-0.4128; p_A= 0.9108; )
# 	change  =(R_E= 9.906696e-07; p_A=-3.643325e+03; )
# 5. step; last_best= 1.11294e+03; absolute_best= 1.11294e+03; step_size= 0.02000
# 	point   =(R_E= 2.795158e-05; p_A=-1.678561e+05; )
# 	output  =1095.1397281319719; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9136; p_A=-0.4067; )
# 	change  =(R_E= 1.096288e-06; p_A= 8.133487e+02; )
# 6. step; last_best= 1.09514e+03; absolute_best= 1.09514e+03; step_size= 0.01000
# 	point   =(R_E= 2.904787e-05; p_A=-1.670427e+05; )
# 	output  =1088.0490079323235; success=True; modifier=1.0;
# 	gradient=(R_E=-0.1018; p_A= 0.9948; )
# 	change  =(R_E= 1.222029e-07; p_A=-1.989602e+03; )
# 7. step; last_best= 1.08802e+03; absolute_best= 1.08802e+03; step_size= 0.01000
# 	point   =(R_E= 2.917007e-05; p_A=-1.690323e+05; )
# 	output  =1079.9913733467713; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9628; p_A=-0.2702; )
# 	change  =(R_E= 5.776880e-07; p_A= 2.701677e+02; )
# 8. step; last_best= 1.07998e+03; absolute_best= 1.07998e+03; step_size= 0.00500
# 	point   =(R_E= 2.974776e-05; p_A=-1.687621e+05; )
# 	output  =1058.8041073189243; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7076; p_A= 0.7067; )
# 	change  =(R_E= 1.698146e-06; p_A=-2.826609e+03; )
# 9. step; last_best= 1.05880e+03; absolute_best= 1.05880e+03; step_size= 0.02000
# 	point   =(R_E= 3.144591e-05; p_A=-1.715888e+05; )
# 	output  =1018.1131002151855; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7805; p_A= 0.6252; )
# 	change  =(R_E= 7.492803e-06; p_A=-1.000249e+04; )
# 10. step; last_best= 1.01811e+03; absolute_best= 1.01811e+03; step_size= 0.08000
# 	point   =(R_E= 3.893871e-05; p_A=-1.815912e+05; )
# 	output  =1018.104155464703; success=True; modifier=0.25;
# 	gradient=(R_E= 0.5309; p_A= 0.8475; )
# 	change  =(R_E=-1.274074e-06; p_A=-3.389828e+03; )
# 11. step; last_best= 1.01807e+03; absolute_best= 1.01807e+03; step_size= 0.02000
# 	point   =(R_E= 3.766464e-05; p_A=-1.849811e+05; )
# 	output  =997.4570210288446; success=True; modifier=0.5;
# 	gradient=(R_E=-0.8616; p_A=-0.5076; )
# 	change  =(R_E= 1.033908e-06; p_A= 1.015211e+03; )
# 12. step; last_best= 9.97449e+02; absolute_best= 9.97449e+02; step_size= 0.01000
# 	point   =(R_E= 3.869854e-05; p_A=-1.839659e+05; )
# 	output  =986.5174950913882; success=True; modifier=2.0;
# 	gradient=(R_E=-0.8916; p_A= 0.4529; )
# 	change  =(R_E= 2.139789e-06; p_A=-1.811462e+03; )
# 13. step; last_best= 9.86517e+02; absolute_best= 9.86517e+02; step_size= 0.02000
# 	point   =(R_E= 4.083833e-05; p_A=-1.857773e+05; )
# 	output  =979.0877761348634; success=True; modifier=0.5;
# 	gradient=(R_E= 0.3857; p_A= 0.9226; )
# 	change  =(R_E=-4.627976e-07; p_A=-1.845278e+03; )
# 14. step; last_best= 9.79074e+02; absolute_best= 9.79074e+02; step_size= 0.01000
# 	point   =(R_E= 4.037554e-05; p_A=-1.876226e+05; )
# 	output  =974.5741421234228; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9976; p_A=-0.0689; )
# 	change  =(R_E= 5.985756e-07; p_A= 6.886389e+01; )
# 15. step; last_best= 9.74570e+02; absolute_best= 9.74570e+02; step_size= 0.00500
# 	point   =(R_E= 4.097411e-05; p_A=-1.875537e+05; )
# 	output  =960.4438717647005; success=True; modifier=4.0;
# 	gradient=(R_E=-0.5219; p_A= 0.8530; )
# 	change  =(R_E= 1.252448e-06; p_A=-3.412141e+03; )
# 16. step; last_best= 9.60432e+02; absolute_best= 9.60432e+02; step_size= 0.02000
# 	point   =(R_E= 4.222656e-05; p_A=-1.909659e+05; )
# 	output  =956.7833967279059; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9963; p_A=-0.0861; )
# 	change  =(R_E= 5.977739e-07; p_A= 8.606105e+01; )
# 17. step; last_best= 9.56780e+02; absolute_best= 9.56780e+02; step_size= 0.00500
# 	point   =(R_E= 4.282433e-05; p_A=-1.908798e+05; )
# 	output  =948.5061042315433; success=True; modifier=4.0;
# 	gradient=(R_E=-0.3919; p_A= 0.9200; )
# 	change  =(R_E= 9.404428e-07; p_A=-3.680114e+03; )
# 18. step; last_best= 9.48491e+02; absolute_best= 9.48491e+02; step_size= 0.02000
# 	point   =(R_E= 4.376478e-05; p_A=-1.945599e+05; )
# 	output  =943.2740815770286; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9430; p_A=-0.3328; )
# 	change  =(R_E= 5.657955e-07; p_A= 3.328141e+02; )
# 19. step; last_best= 9.43268e+02; absolute_best= 9.43268e+02; step_size= 0.00500
# 	point   =(R_E= 4.433057e-05; p_A=-1.942271e+05; )
# 	output  =939.4158041223144; success=True; modifier=2.0;
# 	gradient=(R_E=-0.8927; p_A= 0.4506; )
# 	change  =(R_E= 1.071297e-06; p_A=-9.011134e+02; )
# 20. step; last_best= 9.39416e+02; absolute_best= 9.39416e+02; step_size= 0.01000
# 	point   =(R_E= 4.540187e-05; p_A=-1.951282e+05; )
# 	output  =937.0317710960226; success=True; modifier=0.5;
# 	gradient=(R_E= 0.3246; p_A= 0.9458; )
# 	change  =(R_E=-1.947759e-07; p_A=-9.458423e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 21. step; last_best= 9.37019e+02; absolute_best= 9.37019e+02; step_size= 0.00500
# 	point   =(R_E= 4.520709e-05; p_A=-1.960741e+05; )
# 	output  =935.175755256003; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9702; p_A= 0.2424; )
# 	change  =(R_E= 5.820985e-07; p_A=-2.424491e+02; )
# 22. step; last_best= 9.35176e+02; absolute_best= 9.35176e+02; step_size= 0.00500
# 	point   =(R_E= 4.578919e-05; p_A=-1.963165e+05; )
# 	output  =933.5792556278451; success=True; modifier=1.0;
# 	gradient=(R_E= 0.0658; p_A= 0.9978; )
# 	change  =(R_E=-3.947465e-08; p_A=-9.978334e+02; )
# 23. step; last_best= 9.33572e+02; absolute_best= 9.33572e+02; step_size= 0.00500
# 	point   =(R_E= 4.574972e-05; p_A=-1.973144e+05; )
# 	output  =932.078313810932; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9992; p_A= 0.0400; )
# 	change  =(R_E= 5.995199e-07; p_A=-3.999509e+01; )
# 24. step; last_best= 9.32078e+02; absolute_best= 9.32078e+02; step_size= 0.00500
# 	point   =(R_E= 4.634924e-05; p_A=-1.973543e+05; )
# 	output  =930.718612596537; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1636; p_A= 0.9865; )
# 	change  =(R_E=-9.818657e-08; p_A=-9.865194e+02; )
# 25. step; last_best= 9.30712e+02; absolute_best= 9.30712e+02; step_size= 0.00500
# 	point   =(R_E= 4.625105e-05; p_A=-1.983409e+05; )
# 	output  =929.4428122086068; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9998; p_A=-0.0191; )
# 	change  =(R_E= 5.998908e-07; p_A= 1.907937e+01; )
# 26. step; last_best= 9.29443e+02; absolute_best= 9.29443e+02; step_size= 0.00500
# 	point   =(R_E= 4.685094e-05; p_A=-1.983218e+05; )
# 	output  =928.2977018822705; success=True; modifier=1.0;
# 	gradient=(R_E= 0.2304; p_A= 0.9731; )
# 	change  =(R_E=-1.382307e-07; p_A=-9.730997e+02; )
# 27. step; last_best= 9.28291e+02; absolute_best= 9.28291e+02; step_size= 0.00500
# 	point   =(R_E= 4.671271e-05; p_A=-1.992949e+05; )
# 	output  =927.1894618730865; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9975; p_A=-0.0705; )
# 	change  =(R_E= 2.992536e-07; p_A= 3.524761e+01; )
# 28. step; last_best= 9.27187e+02; absolute_best= 9.27187e+02; step_size= 0.00250
# 	point   =(R_E= 4.701196e-05; p_A=-1.992596e+05; )
# 	output  =923.6969551892594; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6575; p_A= 0.7535; )
# 	change  =(R_E= 7.889411e-07; p_A=-1.506995e+03; )
# 29. step; last_best= 9.23695e+02; absolute_best= 9.23695e+02; step_size= 0.01000
# 	point   =(R_E= 4.780090e-05; p_A=-2.007666e+05; )
# 	output  =920.4129483973863; success=True; modifier=2.0;
# 	gradient=(R_E=-0.4415; p_A= 0.8972; )
# 	change  =(R_E= 1.059683e-06; p_A=-3.588977e+03; )
# 30. step; last_best= 9.20403e+02; absolute_best= 9.20403e+02; step_size= 0.02000
# 	point   =(R_E= 4.886059e-05; p_A=-2.043556e+05; )
# 	output  =918.0763533190552; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8994; p_A=-0.4370; )
# 	change  =(R_E= 5.396681e-07; p_A= 4.370302e+02; )
# 31. step; last_best= 9.18076e+02; absolute_best= 9.18076e+02; step_size= 0.00500
# 	point   =(R_E= 4.940026e-05; p_A=-2.039186e+05; )
# 	output  =917.6535729924209; success=True; modifier=0.5;
# 	gradient=(R_E=-0.0288; p_A= 0.9996; )
# 	change  =(R_E= 8.636983e-09; p_A=-4.997927e+02; )
# 32. step; last_best= 9.17651e+02; absolute_best= 9.17651e+02; step_size= 0.00250
# 	point   =(R_E= 4.940889e-05; p_A=-2.044184e+05; )
# 	output  =917.2661663854702; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9880; p_A= 0.1541; )
# 	change  =(R_E= 2.964146e-07; p_A=-7.707100e+01; )
# 33. step; last_best= 9.17266e+02; absolute_best= 9.17266e+02; step_size= 0.00250
# 	point   =(R_E= 4.970531e-05; p_A=-2.044954e+05; )
# 	output  =916.9097734772782; success=True; modifier=1.0;
# 	gradient=(R_E= 0.1200; p_A= 0.9928; )
# 	change  =(R_E=-3.600755e-08; p_A=-4.963854e+02; )
# 34. step; last_best= 9.16907e+02; absolute_best= 9.16907e+02; step_size= 0.00250
# 	point   =(R_E= 4.966930e-05; p_A=-2.049918e+05; )
# 	output  =916.5730852812484; success=True; modifier=1.0;
# 	gradient=(R_E=-0.9976; p_A= 0.0691; )
# 	change  =(R_E= 2.992832e-07; p_A=-3.454290e+01; )
# 35. step; last_best= 9.16573e+02; absolute_best= 9.16573e+02; step_size= 0.00250
# 	point   =(R_E= 4.996858e-05; p_A=-2.050264e+05; )
# 	output  =916.3053313495853; success=True; modifier=0.5;
# 	gradient=(R_E= 0.1754; p_A= 0.9845; )
# 	change  =(R_E=-2.631594e-08; p_A=-2.461226e+02; )
# 36. step; last_best= 9.16304e+02; absolute_best= 9.16304e+02; step_size= 0.00125
# 	point   =(R_E= 4.994227e-05; p_A=-2.052725e+05; )
# 	output  =915.3810965314532; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6108; p_A= 0.7918; )
# 	change  =(R_E= 3.664694e-07; p_A=-7.917985e+02; )
# 37. step; last_best= 9.15380e+02; absolute_best= 9.15380e+02; step_size= 0.00500
# 	point   =(R_E= 5.030874e-05; p_A=-2.060643e+05; )
# 	output  =913.3138615906089; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7124; p_A= 0.7018; )
# 	change  =(R_E= 1.709678e-06; p_A=-2.807233e+03; )
# 38. step; last_best= 9.13314e+02; absolute_best= 9.13314e+02; step_size= 0.02000
# 	point   =(R_E= 5.201842e-05; p_A=-2.088715e+05; )
# 	output  =913.1860939820552; success=True; modifier=0.25;
# 	gradient=(R_E= 0.6673; p_A= 0.7448; )
# 	change  =(R_E=-4.003570e-07; p_A=-7.448233e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 39. step; last_best= 9.13181e+02; absolute_best= 9.13181e+02; step_size= 0.00500
# 	point   =(R_E= 5.161806e-05; p_A=-2.096164e+05; )
# 	output  =912.4552745088879; success=True; modifier=0.5;
# 	gradient=(R_E=-0.8911; p_A=-0.4538; )
# 	change  =(R_E= 2.673303e-07; p_A= 2.269026e+02; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 40. step; last_best= 9.12454e+02; absolute_best= 9.12454e+02; step_size= 0.00250
# 	point   =(R_E= 5.188539e-05; p_A=-2.093895e+05; )
# 	output  =911.5724291016729; success=True; modifier=4.0;
# 	gradient=(R_E=-0.6000; p_A= 0.8000; )
# 	change  =(R_E= 7.200479e-07; p_A=-1.599940e+03; )
# 41. step; last_best= 9.11572e+02; absolute_best= 9.11572e+02; step_size= 0.01000
# 	point   =(R_E= 5.260544e-05; p_A=-2.109894e+05; )
# 	output  =911.4672456871863; success=True; modifier=0.25;
# 	gradient=(R_E=-0.8476; p_A= 0.5306; )
# 	change  =(R_E= 2.542849e-07; p_A=-2.653049e+02; )
# 42. step; last_best= 9.11467e+02; absolute_best= 9.11467e+02; step_size= 0.00250
# 	point   =(R_E= 5.285972e-05; p_A=-2.112547e+05; )
# 	output  =911.3919420436795; success=True; modifier=0.25;
# 	gradient=(R_E= 0.5170; p_A= 0.8560; )
# 	change  =(R_E=-3.877228e-08; p_A=-1.070009e+02; )
# 43. step; last_best= 9.11392e+02; absolute_best= 9.11392e+02; step_size= 0.00063
# 	point   =(R_E= 5.282095e-05; p_A=-2.113617e+05; )
# 	output  =911.333321613186; success=True; modifier=2.0;
# 	gradient=(R_E=-0.1869; p_A= 0.9824; )
# 	change  =(R_E= 2.802804e-08; p_A=-2.455969e+02; )
# 44. step; last_best= 9.11332e+02; absolute_best= 9.11332e+02; step_size= 0.00125
# 	point   =(R_E= 5.284898e-05; p_A=-2.116073e+05; )
# 	output  =911.2901716952731; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9983; p_A= 0.0576; )
# 	change  =(R_E= 7.487541e-08; p_A=-7.202076e+00; )
# 45. step; last_best= 9.11290e+02; absolute_best= 9.11290e+02; step_size= 0.00063
# 	point   =(R_E= 5.292385e-05; p_A=-2.116145e+05; )
# 	output  =911.2051124135694; success=True; modifier=4.0;
# 	gradient=(R_E=-0.3217; p_A= 0.9469; )
# 	change  =(R_E= 9.649982e-08; p_A=-4.734266e+02; )
# 46. step; last_best= 9.11204e+02; absolute_best= 9.11204e+02; step_size= 0.00250
# 	point   =(R_E= 5.302035e-05; p_A=-2.120879e+05; )
# 	output  =911.1346853145227; success=True; modifier=0.25;
# 	gradient=(R_E=-0.9803; p_A=-0.1976; )
# 	change  =(R_E= 7.352181e-08; p_A= 2.469504e+01; )
# 47. step; last_best= 9.11134e+02; absolute_best= 9.11134e+02; step_size= 0.00063
# 	point   =(R_E= 5.309387e-05; p_A=-2.120632e+05; )
# 	output  =911.1022329197743; success=True; modifier=2.0;
# 	gradient=(R_E=-0.9363; p_A= 0.3512; )
# 	change  =(R_E= 1.404451e-07; p_A=-8.779978e+01; )
# 48. step; last_best= 9.11102e+02; absolute_best= 9.11102e+02; step_size= 0.00125
# 	point   =(R_E= 5.323432e-05; p_A=-2.121510e+05; )
# 	output  =911.0599096160398; success=True; modifier=0.5;
# 	gradient=(R_E= 0.4583; p_A= 0.8888; )
# 	change  =(R_E=-3.437072e-08; p_A=-1.111012e+02; )
# 49. step; last_best= 9.11060e+02; absolute_best= 9.11060e+02; step_size= 0.00063
# 	point   =(R_E= 5.319995e-05; p_A=-2.122621e+05; )
# 	output  =910.9659680022776; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7684; p_A= 0.6400; )
# 	change  =(R_E= 2.305090e-07; p_A=-3.200069e+02; )
# 50. step; last_best= 9.10966e+02; absolute_best= 9.10966e+02; step_size= 0.00250
# 	point   =(R_E= 5.343046e-05; p_A=-2.125821e+05; )
# 	output  =910.927117289734; success=True; modifier=0.25;
# 	gradient=(R_E= 0.4847; p_A= 0.8747; )
# 	change  =(R_E=-3.635535e-08; p_A=-1.093324e+02; )
# 51. step; last_best= 9.10927e+02; absolute_best= 9.10927e+02; step_size= 0.00063
# 	point   =(R_E= 5.339410e-05; p_A=-2.126915e+05; )
# 	output  =910.8035786941854; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7878; p_A= 0.6159; )
# 	change  =(R_E= 2.363432e-07; p_A=-3.079588e+02; )
# 52. step; last_best= 9.10804e+02; absolute_best= 9.10804e+02; step_size= 0.00250
# 	point   =(R_E= 5.363045e-05; p_A=-2.129994e+05; )
# 	output  =910.8189805903204; success=True; modifier=0.25;
# 	gradient=(R_E= 0.7050; p_A= 0.7092; )
# 	change  =(R_E=-5.287589e-08; p_A=-8.864944e+01; )
# 53. step; last_best= 9.10819e+02; absolute_best= 9.10804e+02; step_size= 0.00063
# 	point   =(R_E= 5.357757e-05; p_A=-2.130881e+05; )
# 	output  =910.7757393937488; success=True; modifier=4.0;
# 	gradient=(R_E=-0.8041; p_A= 0.5945; )
# 	change  =(R_E= 2.412352e-07; p_A=-2.972354e+02; )
# 54. step; last_best= 9.10776e+02; absolute_best= 9.10776e+02; step_size= 0.00250
# 	point   =(R_E= 5.381880e-05; p_A=-2.133853e+05; )
# 	output  =910.7247334763982; success=True; modifier=0.25;
# 	gradient=(R_E= 0.6456; p_A= 0.7637; )
# 	change  =(R_E=-4.841748e-08; p_A=-9.546302e+01; )
# 55. step; last_best= 9.10725e+02; absolute_best= 9.10725e+02; step_size= 0.00063
# 	point   =(R_E= 5.377039e-05; p_A=-2.134808e+05; )
# 	output  =910.7036767684368; success=True; modifier=2.0;
# 	gradient=(R_E=-0.2843; p_A= 0.9587; )
# 	change  =(R_E= 4.264462e-08; p_A=-2.396840e+02; )
# 56. step; last_best= 9.10703e+02; absolute_best= 9.10703e+02; step_size= 0.00125
# 	point   =(R_E= 5.381303e-05; p_A=-2.137205e+05; )
# 	output  =910.6841124631972; success=True; modifier=0.5;
# 	gradient=(R_E=-0.9483; p_A=-0.3173; )
# 	change  =(R_E= 7.112438e-08; p_A= 3.966254e+01; )
# 57. step; last_best= 9.10684e+02; absolute_best= 9.10684e+02; step_size= 0.00063
# 	point   =(R_E= 5.388416e-05; p_A=-2.136808e+05; )
# 	output  =910.6752028795241; success=True; modifier=0.5;
# 	gradient=(R_E= 0.3295; p_A= 0.9442; )
# 	change  =(R_E=-1.235647e-08; p_A=-5.900959e+01; )
# 58. step; last_best= 9.10675e+02; absolute_best= 9.10675e+02; step_size= 0.00031
# 	point   =(R_E= 5.387180e-05; p_A=-2.137398e+05; )
# 	output  =910.6646175693626; success=True; modifier=2.0;
# 	gradient=(R_E=-0.9160; p_A= 0.4012; )
# 	change  =(R_E= 6.869887e-08; p_A=-5.015160e+01; )
# 59. step; last_best= 9.10665e+02; absolute_best= 9.10665e+02; step_size= 0.00063
# 	point   =(R_E= 5.394050e-05; p_A=-2.137900e+05; )
# C:\Users\aron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
# 	output  =910.6542151026836; success=True; modifier=0.5;
# 	gradient=(R_E= 0.4149; p_A= 0.9099; )
# 	change  =(R_E=-1.555875e-08; p_A=-5.686669e+01; )
# 60. step; last_best= 9.10654e+02; absolute_best= 9.10654e+02; step_size= 0.00031
# 	point   =(R_E= 5.392494e-05; p_A=-2.138468e+05; )
# 	output  =910.6259931866226; success=True; modifier=4.0;
# 	gradient=(R_E=-0.7565; p_A= 0.6540; )
# 	change  =(R_E= 1.134789e-07; p_A=-1.634908e+02; )
# 61. step; last_best= 9.10626e+02; absolute_best= 9.10626e+02; step_size= 0.00125
# 	point   =(R_E= 5.403842e-05; p_A=-2.140103e+05; )
# 	output  =910.616812809205; success=True; modifier=0.25;
# 	gradient=(R_E= 0.4153; p_A= 0.9097; )
# 	change  =(R_E=-1.557554e-08; p_A=-5.685392e+01; )
# 62. step; last_best= 9.10617e+02; absolute_best= 9.10617e+02; step_size= 0.00031
# 	point   =(R_E= 5.402284e-05; p_A=-2.140672e+05; )
# 	output  =910.6091478160956; success=True; modifier=2.0;
# 	gradient=(R_E=-0.9070; p_A= 0.4211; )
# 	change  =(R_E= 6.802764e-08; p_A=-5.263186e+01; )
# 	Warning, forward point failed, trial_num=1; current_delta=1e-05
# 63. step; last_best= 9.10609e+02; absolute_best= 9.10609e+02; step_size= 0.00063
# 	point   =(R_E= 5.409087e-05; p_A=-2.141198e+05; )
# 	output  =910.5994503503147; success=True; modifier=0.5;
# 	gradient=(R_E= 0.4555; p_A= 0.8902; )
# 	change  =(R_E=-1.708094e-08; p_A=-5.564000e+01; )
# 64. step; last_best= 9.10599e+02; absolute_best= 9.10599e+02; step_size= 0.00031
# 	point   =(R_E= 5.407379e-05; p_A=-2.141754e+05; )
# 	output  =910.5909411478684; success=True; modifier=2.0;
# 	gradient=(R_E=-0.8743; p_A= 0.4853; )
# 	change  =(R_E= 6.557602e-08; p_A=-6.066266e+01; )
# 65. step; last_best= 9.10591e+02; absolute_best= 9.10591e+02; step_size= 0.00063
# 	point   =(R_E= 5.413937e-05; p_A=-2.142361e+05; )
# 	output  =910.5836754989787; success=True; modifier=0.5;
# 	gradient=(R_E= 0.5174; p_A= 0.8558; )
# 	change  =(R_E=-1.940162e-08; p_A=-5.348486e+01; )
# 66. step; last_best= 9.10577e+02; absolute_best= 9.10577e+02; step_size= 0.00031
# 	point   =(R_E= 5.411996e-05; p_A=-2.142896e+05; )
# 	output  =910.5846167770819; success=True; modifier=0.25;
# 	gradient=(R_E= 0.0221; p_A=-0.9998; )
# 	change  =(R_E=-2.069519e-10; p_A= 1.562119e+01; )

# %%
all_central_points = []
central_outputs = []
for points in datas:
    outputs = [data[to_optimize] for data in points]
    central_outputs.append(outputs[0])
    #central_outputs.append(min(outputs))
    all_central_points.append(points[0])
value1 = [data[key1] for data in all_central_points]
value2 = [data[key2] for data in all_central_points]
start = len(all_central_points) // 2
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].plot(value1[:start+1], value2[:start+1], '.-', color='blue', linewidth=1, zorder=1)
ax[0].plot(value1[start:], value2[start:], '.-', color='lightblue', linewidth=0.5, zorder=1)
ax[1].plot(value1[start:], value2[start:], '.-', color='lightblue', linewidth=1, zorder=1)
ax[0].scatter([value1[0]], [value2[0]], color='green', zorder=2, s=25)   # start point
ax[0].scatter([value1[-1]], [value2[-1]], color='red', zorder=2, s=25)   # optimal point
ax[1].scatter([value1[-1]], [value2[-1]], color='red', zorder=2, s=25)   # optimal point
ax[0].text(value1[0], value2[0], f'  start: ({value1[0]:.2e}, {value2[0]:.2e})', fontsize=12)
ax[1].text(value1[-1], value2[-1], f'  end: ({value1[-1]:.2e}, {value2[-1]:.2e})', fontsize=12)
ax[0].set_title('All points')
ax[1].set_title('Near optimal point')
ax[0].set_xlabel(key1)
ax[0].set_ylabel(key2)
ax[1].set_xlabel(key1)
ax[1].set_ylabel(key2)
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(12, 5))
ax.plot(range(len(central_outputs[:])), central_outputs[:], '.-')
ax.set_ylim([0.999*min(central_outputs), 1.05*min(central_outputs)])
ax.set_xticks(range(0, len(central_outputs[:]), 10), minor=False)
ax.set_xticks(range(len(central_outputs[:])), minor=True)
ax.tick_params(which='major', axis='x', width=2, grid_color='darkgrey', grid_linewidth=1.5)
ax.set_xlabel('step number [-]')
ax.set_ylabel(to_optimize)
ax.grid(which='both')
#plt.yscale('log')
plt.show()
print(f'last output: {central_outputs[-1]: .2f}')
# Out:
# last output:  910.58

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 10))
levels = np.linspace(vmin, vmax, 250)
maxi = np.log10(max(central_outputs))
cp = ax.contourf(X, Y, Z, levels=levels, cmap='gist_rainbow', vmax=min(vmax, maxi), extend='max')
ax.contour(X, Y, Z, levels=np.linspace(vmin, vmax, contour_levels), colors='black', linewidths=0.5)
colorbar_title = '$Energy\ demand\ [MJ/kg_{' + gd.de.target_specie + '}]$'
cbar = fig.colorbar(cp, label=colorbar_title) # Add a colorbar to a plot

ax.plot(value1[:], value2[:], '.-', color='blue', linewidth=1, zorder=1)
ax.scatter([value1[0]], [value2[0]], color='green', zorder=2, s=25)   # start point
ax.scatter([value1[-1]], [value2[-1]], color='green', zorder=2, s=25)   # optimal point
ax.text(value1[0], value2[0], f'  start: ({value1[0]:.2e}, {value2[0]:.2e})', fontsize=12)
ax.set_title('All points')
ax.set_xlabel(key1)
ax.set_ylabel(key2)

range1 = max(value1) - min(value1)
range2 = max(value2) - min(value2)
range1 = [min(value1) - 0.05*range1, max(value1) + 0.05*range1]
range2 = [min(value2) - 0.05*range2, max(value2) + 0.05*range2]
ax.set_xlim(range1)
ax.set_ylim(range2)

ticks = cbar.get_ticks()
cbar.set_ticks(ticks)
if use_log10:
    cbar.set_ticklabels([f'{10**tick:.0f}' for tick in ticks])  # Format as powers of 10
else:
    cbar.set_ticklabels([f'{tick:.1f}' for tick in ticks])
cbar.ax.tick_params(labelsize=12)  # Adjust font size
plt.show()
